# %% [markdown]
# **Feedforward Neural Network (FNN)**

# %% [markdown]
# Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import gc
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
import numpy as np
import os
import pandas as pd
import random
import time
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

# %% [markdown]
# Classes / Functions used below

# %%
# Gradient-Based Adaptive Batch Size Class
class GradientAdaptiveBatchingLearning:
    def __init__(self, initial_batch_size=16, initial_lr=0.001, 
                 grad_threshold=0.01, batch_multiplier=1.4, lr_multiplier=0.8, lr_min=0.0005, max_batch_size=142):
        self.current_batch_size = initial_batch_size
        self.current_lr = initial_lr
        self.grad_threshold = grad_threshold
        self.batch_multiplier = batch_multiplier
        self.lr_multiplier = lr_multiplier
        self.lr_min = lr_min
        self.max_batch_size = max_batch_size  # Will be set dynamically to len(X_train)
        self.loss_history = []
        self.update_count = 0
        
    def update_params(self, current_loss, epoch):
        self.loss_history.append(current_loss)
        
        # Need at least 5 epochs of history for gradient calculation
        if len(self.loss_history) >= 5:
            # Calculate gradient (first derivative) over recent losses
            recent_losses = self.loss_history[-5:]
            gradient = np.mean(np.diff(recent_losses))
            
            # Additional stability check: don't update too frequently
            epochs_since_update = len(self.loss_history) - self.update_count
            
            # If gradient is small (slow improvement) and enough time passed
            if abs(gradient) < self.grad_threshold and epochs_since_update >= 10:
                new_batch_size = min(
                    int(self.current_batch_size * self.batch_multiplier), 
                    self.max_batch_size
                )
                # Decrease learning rate when increasing batch size
                lr_scaling = self.lr_multiplier  # self.current_batch_size / new_batch_size
                self.current_lr = max(
                    self.current_lr*lr_scaling, 
                    self.lr_min
                )
                self.current_batch_size = new_batch_size
                self.update_count = len(self.loss_history)
                
                print(f"Epoch {epoch}: Gradient = {gradient:.6f} < {self.grad_threshold}")
                print(f"  → Increased batch size: {int(self.current_batch_size/self.batch_multiplier)} → {self.current_batch_size}")
                print(f"  → Decreased learning rate: {self.current_lr/lr_scaling:.6f} → {self.current_lr:.6f}")

                # if new_batch_size != self.current_batch_size:
                #     # Decrease learning rate when increasing batch size
                #     lr_scaling = self.lr_multiplier  # self.current_batch_size / new_batch_size
                #     self.current_lr *= lr_scaling
                #     self.current_batch_size = new_batch_size
                #     self.update_count = len(self.loss_history)
                    
                #     print(f"Epoch {epoch}: Gradient = {gradient:.6f} < {self.grad_threshold}")
                #     print(f"  → Increased batch size: {int(self.current_batch_size/self.batch_multiplier)} → {self.current_batch_size}")
                #     print(f"  → Decreased learning rate: {self.current_lr/lr_scaling:.6f} → {self.current_lr:.6f}")
                    
        return self.current_batch_size, self.current_lr

# %% [markdown]
# Load csv into df

# %%
# --- Ensure consistent working directory for data loading ---
# This block dynamically sets the current working directory to the Git repository root.
# This makes data paths reliable for all collaborators, regardless of where they open the notebook.

current_dir = os.getcwd()
repo_root = current_dir
while not os.path.exists(os.path.join(repo_root, '.git')):
    # Move up one directory
    parent_dir = os.path.dirname(repo_root)
    if parent_dir == repo_root: # Reached filesystem root, .git not found
        raise FileNotFoundError(
            "Could not find the .git directory. "
            "Please ensure you are running this code from within a Git repository."
        )
    repo_root = parent_dir

# Change the current working directory if it's not already the repo root
if os.getcwd() != repo_root:
    os.chdir(repo_root)
    print(f"Working directory set to: {os.getcwd()}") # Informative print for users


# --- Data Loading ---
# Path to the data file, relative to the repository root.
data_file_name = 'df_eng_customer_purchasing_features.csv'
data_file_path = os.path.join('data', 'processed', data_file_name)

try:
    df = pd.read_csv(data_file_path)
    print(f"Successfully loaded '{data_file_name}' into the DataFrame named df.")
    #print(df.head())
except FileNotFoundError:
    print(f"Error: The file '{data_file_name}' was not found at '{data_file_path}'.")
    print("Please ensure it exists in the 'data/processed/' folder relative to the repository root.")
except Exception as e:
    print(f"An error occurred during data loading: {e}")
# Out:
# Working directory set to: c:\Users\The Winner\DSI\customer_purchasing_behaviour
# Successfully loaded 'df_eng_customer_purchasing_features.csv' into the DataFrame named df.

# %% [markdown]
# Split the data between train portion and a holdout portion that will be used in another Notebook for validation and test

# %%
# Hold out 20% of the dataset (to become val + test in another Notebook, we will not use it here)
X_train, X_holdout, y_train, y_holdout = train_test_split(df.drop(['purchase_amount', 'log_purchase_amount'], axis=1), df[['purchase_amount', 'log_purchase_amount']], test_size=0.2, random_state=42)
df = pd.concat([X_train, y_train], axis=1)

# %% [markdown]
# Prepare data: scale numerical and encode categorical

# %%
# Preprocessing: Prepare Inputs

# Extract relevant columns
numerical_cols = ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'spend_per_purchase', 'spend_to_income_ratio', 'log_annual_income', 'log_purchase_frequency']
categorical_cols = ['region_grouped',  'is_high_value', 'is_champion']
target_col = 'purchase_amount'
target_col_log = 'log_purchase_amount'

# Filter to only use columns that actually exist
existing_numerical_cols = [col for col in numerical_cols if col in df.columns]
existing_categorical_cols = [col for col in categorical_cols if col in df.columns]

# Scale numerical features
scaler = StandardScaler()
X_num = scaler.fit_transform(df[existing_numerical_cols])

# Encode categorical feature
encoder = OneHotEncoder(sparse_output=False)
X_cat = encoder.fit_transform(df[existing_categorical_cols])

# Create DataFrames with distinct column names
num_df = pd.DataFrame(X_num, columns=existing_numerical_cols)
cat_columns = encoder.get_feature_names_out(existing_categorical_cols)
cat_df = pd.DataFrame(X_cat, columns=cat_columns)

# Combine safely
combined_df = pd.concat([num_df, cat_df], axis=1)

# Convert to torch tensor
X_train = torch.tensor(combined_df.values, dtype=torch.float32)

# Target variable
y_train = torch.tensor(df[target_col].values, dtype=torch.float32).view(-1, 1)
y_train_log = torch.tensor(df[target_col_log].values, dtype=torch.float32).view(-1, 1)

############ TARGET Log #########
#y_train = y_train_log

# Print dataset sizes and set max batch sizes
print(f"Dataset sizes:")
print(f"  Train (for KFold CV): {len(X_train)}")
print(f"  Holdout (not used): {len(X_holdout)}")
# Out:
# Dataset sizes:
#   Train (for KFold CV): 190
#   Holdout (not used): 48

# %% [markdown]
# Run Model and log it in MLflow

# %%
# KFold setup
n_folds = 4
kfold = KFold(n_splits=n_folds, shuffle=True, random_state=42)

start_time = time.time()

os.chdir('./experiments/neural_networks') if not load_dotenv() else None
load_dotenv()
print(f"load_dotenv() returned: {load_dotenv()}")
mlflow.set_tracking_uri(os.getenv("MLFLOW_TRACKING_URI"))
mlflow.set_experiment(os.getenv("MLFLOW_EXPERIMENT_NAME"))

# --- lr and batch_size initial values ---
lr = 0.005  # This will be the initial learning rate, will adapt during training
lr_min = 0.0005
batch_size = 16  # Initial batch size instead of fixed batch size
grad_threshold=0.01
batch_multiplier=2
lr_multiplier=0.8
width_1st_layer = 32
width_2nd_layer = 16
width_3rd_layer = 8
width_4th_layer = 4
width_output_layer = 1

# --- Updated params to reflect adaptive nature ---
params = {
    "dataset": data_file_name,
    "width_1st_layer": width_1st_layer,
    "width_2nd_layer": width_2nd_layer,
    "width_3rd_layer": width_3rd_layer,
    "width_4th_layer": width_4th_layer,
    "width_output_layer": width_output_layer,
    "activation": "relu",
    "criterion": "Mean Squared Error (MSE) loss",
    "optimizer": "adam",
    "adaptive_batching_learning_rate": True,  # Flag to indicate adaptive batching
    "initial_lr": lr,  # Renamed to initial_lr
    "initial_batch_size": batch_size,  # Renamed to initial_batch_size
    "max_batch_size": len(X_train),  # Max batch size
    "grad_threshold": grad_threshold,
    "batch_multiplier": batch_multiplier,
    "lr_multiplier": lr_multiplier,
    "lr_min": lr_min
}

# Store results for each fold
fold_results = {
    'val_mse': [], 'val_rmse': [], 'val_mae': [], 'val_mape': [], 'val_r2': [],
    'train_mse': [], 'train_rmse': [], 'train_mae': [], 'train_mape': [], 'train_r2': []
}

# KFold cross-validation loop
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    print(f"\n--- Fold {fold + 1}/{n_folds} ---")
    
    # Create fold-specific train/validation splits
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Make it reproducible
    SEED = 42
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Define the Neural Network Model
    class FeedforwardNN(nn.Module):
        def __init__(self, input_size):
            super(FeedforwardNN, self).__init__()
            self.layers = nn.Sequential(
                nn.Linear(input_size, width_1st_layer),
                nn.ReLU(),
                nn.Linear(width_1st_layer, width_2nd_layer),
                nn.ReLU(),
                nn.Linear(width_2nd_layer, width_3rd_layer),
                nn.ReLU(),
                nn.Linear(width_3rd_layer, width_4th_layer),
                nn.ReLU(),
                nn.Linear(width_4th_layer, width_output_layer)
            )

        def forward(self, x):
            return self.layers(x)

    model = FeedforwardNN(input_size=X_train_fold.shape[1])
    def init_weights(m):
        '''Make the weight initialization reproducible'''
        if isinstance(m, nn.Linear):
            torch.nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                torch.nn.init.constant_(m.bias, 0.01)
    model.apply(init_weights)      

    # Make GPU work
    device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
    
    # Move fold data to device
    X_train_fold = X_train_fold.to(device)
    y_train_fold = y_train_fold.to(device)
    X_val_fold = X_val_fold.to(device)
    y_val_fold = y_val_fold.to(device)
    
    # Initialize adaptive batch trainer
    adaptive_trainer = GradientAdaptiveBatchingLearning(
        initial_batch_size=batch_size,
        initial_lr=lr,
        grad_threshold=grad_threshold,  # Tune this based on your loss scale
        batch_multiplier=batch_multiplier,  # Conservative increase
        lr_multiplier = lr_multiplier,
        lr_min = lr_min,
        max_batch_size=len(X_train_fold)  # Use actual training fold size
    )
    
    # Create DataLoaders with fold data
    train_dataset = TensorDataset(X_train_fold, y_train_fold)
    val_dataset = TensorDataset(X_val_fold, y_val_fold)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Move model to device
    model = model.to(device)

    # Training with MSE & Logging RMSE, MAE
    def compute_rmse(predictions, targets):
        return torch.sqrt(F.mse_loss(predictions, targets))
    def compute_mae(predictions, targets):
        return torch.mean(torch.abs(predictions - targets))
    def compute_mape(predictions, targets):
        return torch.mean(torch.abs((predictions - targets) / targets) * 100)
    def compute_r2(predictions, targets):
        ss_res = torch.sum((targets - predictions) ** 2)
        ss_tot = torch.sum((targets - torch.mean(targets)) ** 2)
        return 1 - ss_res / ss_tot

    # Training loop with adaptive batching ---
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), adaptive_trainer.current_lr)  # Use adaptive LR
    best_val_loss = float('inf')
    patience = 5000
    trigger_times = 0
    min_delta = 0# -0.01
    train_losses = []
    val_losses = []
    # Track batch size and learning rate history
    batch_size_history = []
    lr_history = []

    progress = tqdm(range(10_001), desc=f"Fold {fold+1} Training")
    for epoch in progress:
        # Training phase with batches
        model.train()
        epoch_train_loss = 0.0
        num_train_batches = 0
        
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            output = model(batch_X)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            
            epoch_train_loss += loss.item()
            num_train_batches += 1
        
        avg_train_loss = epoch_train_loss / num_train_batches

        # Validation phase with batches
        model.eval()
        epoch_val_loss = 0.0
        num_val_batches = 0
        
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                val_output = model(batch_X)
                val_loss = criterion(val_output, batch_y)
                epoch_val_loss += val_loss.item()
                num_val_batches += 1
        
        avg_val_loss = epoch_val_loss / num_val_batches
        
        # Adaptive batch size and learning rate update ---
        new_batch_size, new_lr = adaptive_trainer.update_params(avg_val_loss, epoch)
        
        # Update optimizer learning rate if changed
        if new_lr != optimizer.param_groups[0]['lr']:
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
        
        # Create new dataloader if batch size changed
        if new_batch_size != train_loader.batch_size:
            train_loader = DataLoader(train_dataset, batch_size=new_batch_size, shuffle=True)
            # Also update validation loader for consistency
            val_loader = DataLoader(val_dataset, batch_size=new_batch_size, shuffle=False)
        
        # Track history
        batch_size_history.append(new_batch_size)
        lr_history.append(new_lr)
        
        # For progress display
        with torch.no_grad():
            sample_output = model(X_train_fold[:new_batch_size])  # Use current batch size
            sample_rmse = compute_rmse(sample_output, y_train_fold[:new_batch_size])
            # Show current batch size in progress
            progress.set_postfix({
                "Loss": avg_train_loss, 
                "RMSE": sample_rmse.item(),
                "BatchSize": new_batch_size,  # Show current batch size
                "LR": f"{new_lr:.6f}"  # Show current learning rate
            })
        
        # Save losses each epoch
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Early stopping logic
        if avg_val_loss + min_delta < best_val_loss:
            best_val_loss = avg_val_loss
            trigger_times = 0
        else:
            trigger_times += 1
            if trigger_times >= patience:
                print(f"\n⏹️ Early stopping at epoch {epoch} — no validation improvement after {patience} epochs.")
                
                model.eval()
                with torch.no_grad():
                    train_output = model(X_train_fold)
                    val_output = model(X_val_fold)
                    train_loss_final = criterion(train_output, y_train_fold)
                    val_loss_final = criterion(val_output, y_val_fold)
                    
                    rmse = compute_rmse(train_output, y_train_fold)
                    mae = compute_mae(train_output, y_train_fold)
                    r2 = compute_r2(train_output, y_train_fold)
                    val_rmse = compute_rmse(val_output, y_val_fold)
                    val_mae = compute_mae(val_output, y_val_fold)
                    val_r2 = compute_r2(val_output, y_val_fold)
                    
                print(f"Train → MSE = {train_loss_final.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
                print(f"Val   → MSE = {val_loss_final.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")
                break

        if epoch % 10_000 == 0:
            model.eval()
            with torch.no_grad():
                train_output = model(X_train_fold)
                val_output = model(X_val_fold)
                train_loss_full = criterion(train_output, y_train_fold)
                val_loss_full = criterion(val_output, y_val_fold)
                
                rmse = compute_rmse(train_output, y_train_fold)
                mae = compute_mae(train_output, y_train_fold)
                r2 = compute_r2(train_output, y_train_fold)
                val_rmse = compute_rmse(val_output, y_val_fold)
                val_mae = compute_mae(val_output, y_val_fold)
                val_r2 = compute_r2(val_output, y_val_fold)
                
            print(f"Epoch {epoch}:")
            print(f"Train → MSE = {train_loss_full.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
            print(f"Val   → MSE = {val_loss_full.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")

    # Metrics after all the epochs - training
    model.eval()
    with torch.no_grad():
        # Get final predictions on full datasets
        train_output = model(X_train_fold)
        val_output = model(X_val_fold)
        
        # Training metrics
        training_mse = criterion(train_output, y_train_fold)
        training_rmse = compute_rmse(train_output, y_train_fold)
        training_mae = compute_mae(train_output, y_train_fold)
        training_mape = compute_mape(train_output, y_train_fold)
        training_r2_score = compute_r2(train_output, y_train_fold)
    
        # Validation metrics
        val_mse = criterion(val_output, y_val_fold)
        val_rmse = compute_rmse(val_output, y_val_fold)
        val_mae = compute_mae(val_output, y_val_fold)
        val_mape = compute_mape(val_output, y_val_fold)
        val_r2_score = compute_r2(val_output, y_val_fold)
        
        print(f"\nFold {fold+1} Final Results:")
        print(f"Train → MSE = {training_mse.item():.4f}, RMSE = {training_rmse.item():.4f}, MAE = {training_mae.item():.4f}, R² Score = {training_r2_score.item():.4f}")
        print(f"Val   → MSE = {val_mse.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² Score = {val_r2_score.item():.4f}")

    # Individual fold MLflow logging - only keeping CV summary

    # Store fold results
    fold_results['train_mse'].append(training_mse.item())
    fold_results['train_rmse'].append(training_rmse.item())
    fold_results['train_mae'].append(training_mae.item())
    fold_results['train_mape'].append(training_mape.item())
    fold_results['train_r2'].append(training_r2_score.item())
    
    fold_results['val_mse'].append(val_mse.item())
    fold_results['val_rmse'].append(val_rmse.item())
    fold_results['val_mae'].append(val_mae.item())
    fold_results['val_mape'].append(val_mape.item())
    fold_results['val_r2'].append(val_r2_score.item())

    # Enhanced plotting with adaptive batching info
    start = 100 
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves (existing plot)
    ax1.plot(range(start, len(train_losses)), train_losses[start:], label='Training Loss', color='blue')
    ax1.plot(range(start, len(val_losses)), val_losses[start:], label='Validation Loss', color='orange')
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.set_title(f"Loss Curves - Fold {fold+1}")
    ax1.legend()
    ax1.grid(True)
    
    # Batch size evolution
    ax2.plot(batch_size_history, color='green')
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Batch Size")
    ax2.set_title(f"Batch Size Evolution - Fold {fold+1}")
    ax2.grid(True)
    
    # Learning rate evolution
    ax3.plot(lr_history, color='red')
    ax3.set_xlabel("Epoch")
    ax3.set_ylabel("Learning Rate")
    ax3.set_title(f"Learning Rate Evolution - Fold {fold+1}")
    ax3.grid(True)
    
    # Validation loss gradient (to visualize why batch size changed)
    if len(val_losses) > 50:
        val_gradients = np.diff(val_losses)
        ax4.plot(val_gradients[-min(10000, len(val_gradients)):], color='orange', alpha=0.7)
        ax4.axhline(y=adaptive_trainer.grad_threshold, color='red', linestyle='--', 
                    label=f'Threshold: {adaptive_trainer.grad_threshold}')
        ax4.axhline(y=-adaptive_trainer.grad_threshold, color='red', linestyle='--')
        ax4.set_xlabel("Epoch")
        ax4.set_ylabel("Validation Loss Gradient")
        ax4.set_title(f"Recent Validation Loss Gradient - Fold {fold+1}")
        ax4.legend()
        ax4.grid(True)
    
    plt.tight_layout()   
    # Log this fold's plot to MLflow immediately
    plot_filename = f"fold_{fold+1}_training_plots.png"
    plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
    # after show, it deletes the plot
    plt.show()
    
    # Log to MLflow in a separate run for this fold
    fold_run_name = f"Fold_{fold+1}_lr{lr}_bs{batch_size}_w{width_1st_layer}x{width_2nd_layer}x{width_3rd_layer}x{width_4th_layer}"
    with mlflow.start_run(run_name=fold_run_name):
        # Log fold-specific parameters
        fold_params = params.copy()
        fold_params["fold"] = fold + 1
        fold_params["max_batch_size"] = len(X_train_fold)
        mlflow.log_params(fold_params)
        
        # Log the plot artifact
        mlflow.log_artifact(plot_filename)
        
    plt.close()  # Close to free memory
    os.remove(plot_filename)  # Clean up the file
    
    # Print summary of adaptive batching
    print(f"\n📊 Adaptive Batching Summary - Fold {fold+1}:")
    print(f"  Initial batch size: {batch_size}")
    print(f"  Final batch size: {batch_size_history[-1]}")
    print(f"  Initial learning rate: {lr:.6f}")
    print(f"  Final learning rate: {lr_history[-1]:.6f}")
    print(f"  Number of batch size increases: {len(set(batch_size_history)) - 1}")

    # Clean memory in case we want to run this cell again without running the whole notebook
    # remove references to GPU objects 
    del model
    # Invoke garbage collector
    gc.collect()
    # Clear GPU cache
    torch.cuda.empty_cache()

# Compute and log cross-validation summary statistics
print(f"\n{'='*60}")
print(f"Cross-Validation Summary")
print(f"{'='*60}")

cv_summary = {}
for metric_name, values in fold_results.items():
    mean_val = np.mean(values)
    std_val = np.std(values)
    cv_summary[f"{metric_name}_mean"] = mean_val
    cv_summary[f"{metric_name}_std"] = std_val
    print(f"{metric_name}: {mean_val:.4f} ± {std_val:.4f}")

# Log cross-validation summary to MLflow
# Set custom run name
run_name = f"KFold_CV_SUMMARY_lr{lr}_bs{batch_size}_w{width_1st_layer}x{width_2nd_layer}x{width_3rd_layer}x{width_4th_layer}_gt{grad_threshold}"
with mlflow.start_run(run_name=run_name):
    # Log hyperparameter configuration
    summary_params = params.copy()
    summary_params["n_folds"] = n_folds
    summary_params["cv_summary"] = True
    mlflow.log_params(summary_params)
    
    # Log all CV summary metrics
    for metric_name, metric_value in cv_summary.items():
        mlflow.log_metric(metric_name, round(metric_value, 4))

# Clean memory in case we want to run this cell again without running the whole notebook
# Invoke garbage collector
gc.collect()
# Clear GPU cache
torch.cuda.empty_cache()

end_time = time.time()
elapsed_time = end_time - start_time
print(f"\n⏳ Training completed in {elapsed_time:.2f} seconds.")
# Out:
# load_dotenv() returned: True
#
# --- Fold 1/4 ---
# Fold 1 Training:   0%|          | 0/10001 [00:00<?, ?it/s]
# Epoch 0:
# Train → MSE = 203423.4844, RMSE = 451.0249, MAE = 431.7799, R² = -11.0269
# Val   → MSE = 191876.7188, RMSE = 438.0374, MAE = 409.7406, R² = -7.0480
# Epoch 161: Gradient = -0.009543 < 0.01
#   → Increased batch size: 16 → 32
#   → Decreased learning rate: 0.005000 → 0.004000
# Epoch 176: Gradient = 0.000431 < 0.01
#   → Increased batch size: 32 → 64
#   → Decreased learning rate: 0.004000 → 0.003200
# Epoch 188: Gradient = -0.002755 < 0.01
#   → Increased batch size: 64 → 128
#   → Decreased learning rate: 0.003200 → 0.002560
# Epoch 198: Gradient = -0.009898 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.002560 → 0.002048
# Epoch 215: Gradient = -0.008319 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.002048 → 0.001638
# Epoch 225: Gradient = -0.000514 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001638 → 0.001311
# Epoch 235: Gradient = -0.000175 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001311 → 0.001049
# Epoch 245: Gradient = -0.002716 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001049 → 0.000839
# Epoch 255: Gradient = -0.001699 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000839 → 0.000671
# Epoch 265: Gradient = -0.000873 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000671 → 0.000537
# Epoch 275: Gradient = -0.000810 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 285: Gradient = -0.000884 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 295: Gradient = -0.000916 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 305: Gradient = -0.000915 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 315: Gradient = -0.000890 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 325: Gradient = -0.000872 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 335: Gradient = -0.000884 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 345: Gradient = -0.000893 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 355: Gradient = -0.000892 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 365: Gradient = -0.000900 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 375: Gradient = -0.000895 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 385: Gradient = -0.000907 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 395: Gradient = -0.000902 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 405: Gradient = -0.000901 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 415: Gradient = -0.000911 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 425: Gradient = -0.000916 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 435: Gradient = -0.000917 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 445: Gradient = -0.000924 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 455: Gradient = -0.000937 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 465: Gradient = -0.000933 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 475: Gradient = -0.000933 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 485: Gradient = -0.000946 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 495: Gradient = -0.000940 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 505: Gradient = -0.000957 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 515: Gradient = -0.000959 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 525: Gradient = -0.000948 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 535: Gradient = -0.000967 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 545: Gradient = -0.000965 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 555: Gradient = -0.000972 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 565: Gradient = -0.000970 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 575: Gradient = -0.000974 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 585: Gradient = -0.000994 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 595: Gradient = -0.000994 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 605: Gradient = -0.000996 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 615: Gradient = -0.001001 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 625: Gradient = -0.001003 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 635: Gradient = -0.001007 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 645: Gradient = -0.001010 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 655: Gradient = -0.001022 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 665: Gradient = -0.001017 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 675: Gradient = -0.001030 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 685: Gradient = -0.001033 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 695: Gradient = -0.001028 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 705: Gradient = -0.001030 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 715: Gradient = -0.001035 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 725: Gradient = -0.001031 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 735: Gradient = -0.001048 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 745: Gradient = -0.001033 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 755: Gradient = -0.001049 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 765: Gradient = -0.001047 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 775: Gradient = -0.001045 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 785: Gradient = -0.001044 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 795: Gradient = -0.001048 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 805: Gradient = -0.001059 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 815: Gradient = -0.001047 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 825: Gradient = -0.001065 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 835: Gradient = -0.001061 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 845: Gradient = -0.001066 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 855: Gradient = -0.001086 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 865: Gradient = -0.001076 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 875: Gradient = -0.001089 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 885: Gradient = -0.001094 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 895: Gradient = -0.001105 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 905: Gradient = -0.001095 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 915: Gradient = -0.001106 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 925: Gradient = -0.001109 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 935: Gradient = -0.001115 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 945: Gradient = -0.001114 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 955: Gradient = -0.001118 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 965: Gradient = -0.001118 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 975: Gradient = -0.001121 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 985: Gradient = -0.001147 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 995: Gradient = -0.001145 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1005: Gradient = -0.001119 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1015: Gradient = -0.001130 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1025: Gradient = -0.001151 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1035: Gradient = -0.001160 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1045: Gradient = -0.001155 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1055: Gradient = -0.001161 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1065: Gradient = -0.001163 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1075: Gradient = -0.001170 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1085: Gradient = -0.001169 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1095: Gradient = -0.001168 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1105: Gradient = -0.001192 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1115: Gradient = -0.001182 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1125: Gradient = -0.001191 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1135: Gradient = -0.001193 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1145: Gradient = -0.001195 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1155: Gradient = -0.001195 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1165: Gradient = -0.001196 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1175: Gradient = -0.001205 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1185: Gradient = -0.001200 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1195: Gradient = -0.001206 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1205: Gradient = -0.001191 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1215: Gradient = -0.001194 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1225: Gradient = -0.001208 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1235: Gradient = -0.001210 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1245: Gradient = -0.001232 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1255: Gradient = -0.001213 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1265: Gradient = -0.001216 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1275: Gradient = -0.001213 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1285: Gradient = -0.001232 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1295: Gradient = -0.001233 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1305: Gradient = -0.001234 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1315: Gradient = -0.001227 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1325: Gradient = -0.001253 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1335: Gradient = -0.001244 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1345: Gradient = -0.001243 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1355: Gradient = -0.001239 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1365: Gradient = -0.001241 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1375: Gradient = -0.001259 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1385: Gradient = -0.001256 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1395: Gradient = -0.001260 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1405: Gradient = -0.001263 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1415: Gradient = -0.001272 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1425: Gradient = -0.001293 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1435: Gradient = -0.001284 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1445: Gradient = -0.001283 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1455: Gradient = -0.001279 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1465: Gradient = -0.001294 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1475: Gradient = -0.001288 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1485: Gradient = -0.001295 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1495: Gradient = -0.001274 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1505: Gradient = -0.001282 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1515: Gradient = -0.001276 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1525: Gradient = -0.001289 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1535: Gradient = -0.001309 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1545: Gradient = -0.001300 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1555: Gradient = -0.001297 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1565: Gradient = -0.001307 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1575: Gradient = -0.001318 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1585: Gradient = -0.001310 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1595: Gradient = -0.001323 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1605: Gradient = -0.001384 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1615: Gradient = -0.001415 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1625: Gradient = -0.001411 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1635: Gradient = -0.001381 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1645: Gradient = -0.001382 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1655: Gradient = -0.001393 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1665: Gradient = -0.001388 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1675: Gradient = -0.001375 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1685: Gradient = -0.001377 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1695: Gradient = -0.001390 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1705: Gradient = -0.001381 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1715: Gradient = -0.001388 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1725: Gradient = -0.001394 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1735: Gradient = -0.001380 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1745: Gradient = -0.001395 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1755: Gradient = -0.001379 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1765: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1775: Gradient = -0.001390 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1785: Gradient = -0.001400 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1795: Gradient = -0.001396 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1805: Gradient = -0.001404 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1815: Gradient = -0.001412 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1825: Gradient = -0.001404 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1835: Gradient = -0.001395 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1845: Gradient = -0.001405 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1855: Gradient = -0.001401 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1865: Gradient = -0.001414 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1875: Gradient = -0.001405 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1885: Gradient = -0.001407 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1895: Gradient = -0.001407 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1905: Gradient = -0.001406 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1915: Gradient = -0.001416 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1925: Gradient = -0.001408 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1935: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1945: Gradient = -0.001422 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1955: Gradient = -0.001415 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1965: Gradient = -0.001403 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1975: Gradient = -0.001419 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1985: Gradient = -0.001417 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1995: Gradient = -0.001428 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2005: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2015: Gradient = -0.001411 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2025: Gradient = -0.001423 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2035: Gradient = -0.001414 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2045: Gradient = -0.001409 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2055: Gradient = -0.001407 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2065: Gradient = -0.001440 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2075: Gradient = -0.001435 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2085: Gradient = -0.001432 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2095: Gradient = -0.001436 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2105: Gradient = -0.001426 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2115: Gradient = -0.001434 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2125: Gradient = -0.001425 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2135: Gradient = -0.001417 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2145: Gradient = -0.001426 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2155: Gradient = -0.001443 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2165: Gradient = -0.001426 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2175: Gradient = -0.001421 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2185: Gradient = -0.001421 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2195: Gradient = -0.001423 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2205: Gradient = -0.001427 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2215: Gradient = -0.001422 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2225: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2235: Gradient = -0.001425 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2245: Gradient = -0.001435 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2255: Gradient = -0.001437 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2265: Gradient = -0.001423 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2275: Gradient = -0.001430 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2285: Gradient = -0.001424 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2295: Gradient = -0.001429 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2305: Gradient = -0.001419 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2315: Gradient = -0.001432 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2325: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2335: Gradient = -0.001421 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2345: Gradient = -0.001424 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2355: Gradient = -0.001434 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2365: Gradient = -0.001421 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2375: Gradient = -0.001420 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2385: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2395: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2405: Gradient = -0.001430 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2415: Gradient = -0.001426 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2425: Gradient = -0.001429 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2435: Gradient = -0.001426 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2445: Gradient = -0.001431 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2455: Gradient = -0.001407 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2465: Gradient = -0.001425 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2475: Gradient = -0.001419 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2485: Gradient = -0.001409 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2495: Gradient = -0.001425 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2505: Gradient = -0.001406 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2515: Gradient = -0.001427 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2525: Gradient = -0.001420 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2535: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2545: Gradient = -0.001433 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2555: Gradient = -0.001447 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2565: Gradient = -0.001451 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2575: Gradient = -0.001466 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2585: Gradient = -0.001465 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2595: Gradient = -0.001450 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2605: Gradient = -0.001466 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2615: Gradient = -0.001448 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2625: Gradient = -0.001448 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2635: Gradient = -0.001466 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2645: Gradient = -0.001448 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2655: Gradient = -0.001464 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2665: Gradient = -0.001445 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2675: Gradient = -0.001460 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2685: Gradient = -0.001447 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2695: Gradient = -0.001448 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2705: Gradient = -0.001448 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2715: Gradient = -0.001450 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2725: Gradient = -0.001442 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2735: Gradient = -0.001442 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2745: Gradient = -0.001449 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2755: Gradient = -0.001422 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2765: Gradient = -0.001442 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2775: Gradient = -0.001434 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2785: Gradient = -0.001431 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2795: Gradient = -0.001433 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2805: Gradient = -0.001428 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2815: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2825: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2835: Gradient = -0.001421 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2845: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2855: Gradient = -0.001414 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2865: Gradient = -0.001414 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2875: Gradient = -0.001419 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2885: Gradient = -0.001403 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2895: Gradient = -0.001398 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2905: Gradient = -0.001410 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2915: Gradient = -0.001390 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2925: Gradient = -0.001383 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2935: Gradient = -0.001401 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2945: Gradient = -0.001386 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2955: Gradient = -0.001390 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2965: Gradient = -0.001382 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2975: Gradient = -0.001388 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2985: Gradient = -0.001381 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2995: Gradient = -0.001371 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3005: Gradient = -0.001382 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3015: Gradient = -0.001369 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3025: Gradient = -0.001366 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3035: Gradient = -0.001370 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3045: Gradient = -0.001358 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3055: Gradient = -0.001371 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3065: Gradient = -0.001353 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3075: Gradient = -0.001363 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3085: Gradient = -0.001346 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3095: Gradient = -0.001338 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3105: Gradient = -0.001356 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3115: Gradient = -0.001329 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3125: Gradient = -0.001341 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3135: Gradient = -0.001320 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3145: Gradient = -0.001324 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3155: Gradient = -0.001306 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3165: Gradient = -0.001332 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3175: Gradient = -0.001306 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3185: Gradient = -0.001316 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3195: Gradient = -0.001313 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3205: Gradient = -0.001294 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3215: Gradient = -0.001308 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3225: Gradient = -0.001301 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3235: Gradient = -0.001311 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3245: Gradient = -0.001292 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3255: Gradient = -0.001295 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3265: Gradient = -0.001310 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3275: Gradient = -0.001298 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3285: Gradient = -0.001294 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3295: Gradient = -0.001293 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3305: Gradient = -0.001292 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3315: Gradient = -0.001281 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3325: Gradient = -0.001283 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3335: Gradient = -0.001271 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3345: Gradient = -0.001328 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3355: Gradient = -0.001443 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3365: Gradient = -0.001422 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3375: Gradient = -0.001392 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3385: Gradient = -0.001384 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3395: Gradient = -0.001377 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3405: Gradient = -0.001362 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3415: Gradient = -0.001354 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3425: Gradient = -0.001338 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3435: Gradient = -0.001329 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3445: Gradient = -0.001337 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3455: Gradient = -0.001318 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3465: Gradient = -0.001330 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3475: Gradient = -0.001309 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3485: Gradient = -0.001301 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3495: Gradient = -0.001301 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3505: Gradient = -0.001278 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3515: Gradient = -0.001306 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3525: Gradient = -0.001270 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3535: Gradient = -0.001291 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3545: Gradient = -0.001292 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3555: Gradient = -0.001280 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3565: Gradient = -0.001270 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3575: Gradient = -0.001291 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3585: Gradient = -0.001252 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3595: Gradient = -0.001258 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3605: Gradient = -0.001252 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3615: Gradient = -0.001254 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3625: Gradient = -0.001239 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3635: Gradient = -0.001229 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3645: Gradient = -0.001223 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3655: Gradient = -0.001215 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3665: Gradient = -0.001214 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3675: Gradient = -0.001214 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3685: Gradient = -0.001211 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3695: Gradient = -0.001179 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3705: Gradient = -0.001216 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3715: Gradient = -0.001171 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3725: Gradient = -0.001191 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3735: Gradient = -0.001178 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3745: Gradient = -0.001180 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3755: Gradient = -0.001171 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3765: Gradient = -0.001160 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3775: Gradient = -0.001176 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3785: Gradient = -0.001134 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3795: Gradient = -0.001171 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3805: Gradient = -0.001136 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3815: Gradient = -0.001148 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3825: Gradient = -0.001133 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3835: Gradient = -0.001170 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3845: Gradient = -0.001165 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3855: Gradient = -0.001095 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3865: Gradient = -0.000859 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3875: Gradient = -0.001117 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3885: Gradient = -0.001000 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3895: Gradient = -0.001072 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3905: Gradient = -0.000919 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3915: Gradient = -0.000953 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3925: Gradient = -0.000960 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3935: Gradient = -0.000951 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3945: Gradient = -0.000950 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3955: Gradient = -0.000956 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3965: Gradient = -0.000948 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3975: Gradient = -0.000913 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3985: Gradient = -0.000999 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3995: Gradient = -0.000890 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4005: Gradient = -0.000934 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4015: Gradient = -0.000891 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4025: Gradient = -0.000969 < 0.01
#   → Increased batch size: 71 → 142
# ...
# Epoch 8821: Gradient = -0.000075 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8831: Gradient = -0.000035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8841: Gradient = -0.000097 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8851: Gradient = -0.000064 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8861: Gradient = -0.000085 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8871: Gradient = -0.000104 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8881: Gradient = -0.000088 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8891: Gradient = -0.000093 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8901: Gradient = 0.000010 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8911: Gradient = -0.000052 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8921: Gradient = -0.000086 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8931: Gradient = -0.000024 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8941: Gradient = -0.000133 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8951: Gradient = -0.000070 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8961: Gradient = -0.000054 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8971: Gradient = -0.000036 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8981: Gradient = 0.000077 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8991: Gradient = 0.000082 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9001: Gradient = 0.000005 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9011: Gradient = -0.000038 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9021: Gradient = -0.000049 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9031: Gradient = -0.000032 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9041: Gradient = -0.000095 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9051: Gradient = -0.000104 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9061: Gradient = 0.000035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9071: Gradient = 0.000091 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9081: Gradient = 0.000036 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9091: Gradient = -0.000085 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9101: Gradient = -0.000032 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9111: Gradient = -0.000023 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9121: Gradient = -0.000155 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9131: Gradient = 0.000047 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9141: Gradient = 0.000171 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9151: Gradient = -0.000103 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9161: Gradient = -0.000081 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9171: Gradient = 0.000047 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9181: Gradient = -0.000130 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9191: Gradient = -0.000048 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9201: Gradient = 0.000038 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9211: Gradient = 0.000018 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9221: Gradient = -0.000132 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9231: Gradient = 0.000085 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9241: Gradient = -0.000077 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9251: Gradient = -0.000016 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9261: Gradient = -0.000006 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9271: Gradient = -0.000087 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9281: Gradient = 0.000020 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9291: Gradient = -0.000025 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9301: Gradient = 0.000043 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9311: Gradient = -0.000091 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9321: Gradient = 0.000035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9331: Gradient = -0.000057 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9341: Gradient = 0.000033 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9351: Gradient = -0.000087 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9361: Gradient = 0.000014 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9371: Gradient = -0.000111 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9381: Gradient = 0.000014 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9391: Gradient = -0.000055 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9401: Gradient = -0.000010 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9411: Gradient = 0.000010 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9421: Gradient = -0.000103 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9431: Gradient = 0.000019 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9441: Gradient = -0.000087 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9451: Gradient = -0.000020 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9461: Gradient = -0.000042 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9471: Gradient = -0.000128 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9481: Gradient = 0.000033 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9491: Gradient = 0.000110 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9501: Gradient = -0.000100 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9511: Gradient = -0.000035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9521: Gradient = 0.000086 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9531: Gradient = -0.000049 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9541: Gradient = -0.000026 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9551: Gradient = -0.000001 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9561: Gradient = -0.000031 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9571: Gradient = -0.000035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9581: Gradient = -0.000055 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9591: Gradient = -0.000025 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9601: Gradient = 0.000016 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9611: Gradient = -0.000038 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9621: Gradient = -0.000056 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9631: Gradient = 0.000000 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9641: Gradient = 0.000026 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9651: Gradient = -0.000058 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9661: Gradient = -0.000038 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9671: Gradient = 0.000041 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9681: Gradient = 0.000032 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9691: Gradient = 0.000013 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9701: Gradient = -0.000033 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9711: Gradient = -0.000054 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9721: Gradient = -0.000007 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9731: Gradient = 0.000027 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9741: Gradient = 0.000034 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9751: Gradient = -0.000051 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9761: Gradient = -0.000078 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9771: Gradient = -0.000069 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9781: Gradient = -0.000041 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9791: Gradient = 0.000067 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9801: Gradient = 0.000075 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9811: Gradient = -0.000070 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9821: Gradient = -0.000009 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9831: Gradient = -0.000026 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9841: Gradient = -0.000037 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9851: Gradient = -0.000021 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9861: Gradient = 0.000017 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9871: Gradient = -0.000030 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9881: Gradient = -0.000066 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9891: Gradient = -0.000012 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9901: Gradient = -0.000028 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9911: Gradient = -0.000012 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9921: Gradient = 0.000067 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9931: Gradient = 0.000057 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9941: Gradient = 0.000057 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9951: Gradient = 0.000038 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9961: Gradient = 0.000075 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9971: Gradient = -0.000006 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9981: Gradient = 0.000053 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9991: Gradient = 0.000006 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 10000:
# Train → MSE = 0.1421, RMSE = 0.3770, MAE = 0.2531, R² = 1.0000
# Val   → MSE = 0.1906, RMSE = 0.4366, MAE = 0.3110, R² = 1.0000
#
# Fold 4 Final Results:
# Train → MSE = 0.1421, RMSE = 0.3770, MAE = 0.2531, R² Score = 1.0000
# Val   → MSE = 0.1906, RMSE = 0.4366, MAE = 0.3110, R² Score = 1.0000
# 🏃 View run Fold_4_lr0.005_bs16_w32x16x8x4 at: http://localhost:5000/#/experiments/408745732833894938/runs/0089e9c106704f34933b2e7f604c44bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/408745732833894938
#
# 📊 Adaptive Batching Summary - Fold 4:
#   Initial batch size: 16
#   Final batch size: 143
#   Initial learning rate: 0.005000
#   Final learning rate: 0.000500
#   Number of batch size increases: 4
#
# ============================================================
# Cross-Validation Summary
# ============================================================
# val_mse: 0.5943 ± 0.3685
# val_rmse: 0.7342 ± 0.2350
# val_mae: 0.3743 ± 0.0851
# val_mape: 0.1159 ± 0.0323
# val_r2: 1.0000 ± 0.0000
# train_mse: 0.1229 ± 0.0172
# train_rmse: 0.3496 ± 0.0245
# train_mae: 0.2312 ± 0.0208
# train_mape: 0.0551 ± 0.0080
# train_r2: 1.0000 ± 0.0000
# 🏃 View run KFold_CV_SUMMARY_lr0.005_bs16_w32x16x8x4_gt0.01 at: http://localhost:5000/#/experiments/408745732833894938/runs/e13f2bae16444af0b12c95431e95051a
# 🧪 View experiment at: http://localhost:5000/#/experiments/408745732833894938
#
# ⏳ Training completed in 464.61 seconds.

# %% [markdown]
#  Note for the record, biggest net calculated:
#  lr0.005_bs16_w8192x4096x2048x1024
#  Training completed in 2648.41 seconds.
