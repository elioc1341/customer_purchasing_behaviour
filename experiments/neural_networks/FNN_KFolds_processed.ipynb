# %% [markdown]
# **Feedforward Neural Network (FNN)**

# %% [markdown]
# Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import gc
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, KFold  # ADDED: KFold import
import numpy as np
import os
import pandas as pd
import random
import time
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

# %% [markdown]
# Classes / Functions used below

# %%
# Gradient-Based Adaptive Batch Size Class
class GradientAdaptiveBatchingLearning:
    def __init__(self, initial_batch_size=16, initial_lr=0.001, 
                 grad_threshold=0.01, batch_multiplier=1.4, lr_multiplier=0.8, lr_min=0.0005, max_batch_size=142):
        self.current_batch_size = initial_batch_size
        self.current_lr = initial_lr
        self.grad_threshold = grad_threshold
        self.batch_multiplier = batch_multiplier
        self.lr_multiplier = lr_multiplier
        self.lr_min = lr_min
        self.max_batch_size = max_batch_size  # Will be set dynamically to len(X_train)
        self.loss_history = []
        self.update_count = 0
        
    def update_params(self, current_loss, epoch):
        self.loss_history.append(current_loss)
        
        # Need at least 5 epochs of history for gradient calculation
        if len(self.loss_history) >= 5:
            # Calculate gradient (first derivative) over recent losses
            recent_losses = self.loss_history[-5:]
            gradient = np.mean(np.diff(recent_losses))
            
            # Additional stability check: don't update too frequently
            epochs_since_update = len(self.loss_history) - self.update_count
            
            # If gradient is small (slow improvement) and enough time passed
            if abs(gradient) < self.grad_threshold and epochs_since_update >= 10:
                new_batch_size = min(
                    int(self.current_batch_size * self.batch_multiplier), 
                    self.max_batch_size
                )
                # Decrease learning rate when increasing batch size
                lr_scaling = self.lr_multiplier  # self.current_batch_size / new_batch_size
                self.current_lr = max(
                    self.current_lr*lr_scaling, 
                    self.lr_min
                )
                self.current_batch_size = new_batch_size
                self.update_count = len(self.loss_history)
                
                print(f"Epoch {epoch}: Gradient = {gradient:.6f} < {self.grad_threshold}")
                print(f"  → Increased batch size: {int(self.current_batch_size/self.batch_multiplier)} → {self.current_batch_size}")
                print(f"  → Decreased learning rate: {self.current_lr/lr_scaling:.6f} → {self.current_lr:.6f}")

                # if new_batch_size != self.current_batch_size:
                #     # Decrease learning rate when increasing batch size
                #     lr_scaling = self.lr_multiplier  # self.current_batch_size / new_batch_size
                #     self.current_lr *= lr_scaling
                #     self.current_batch_size = new_batch_size
                #     self.update_count = len(self.loss_history)
                    
                #     print(f"Epoch {epoch}: Gradient = {gradient:.6f} < {self.grad_threshold}")
                #     print(f"  → Increased batch size: {int(self.current_batch_size/self.batch_multiplier)} → {self.current_batch_size}")
                #     print(f"  → Decreased learning rate: {self.current_lr/lr_scaling:.6f} → {self.current_lr:.6f}")
                    
        return self.current_batch_size, self.current_lr

# %% [markdown]
# Load csv into df

# %%
# --- Ensure consistent working directory for data loading ---
# This block dynamically sets the current working directory to the Git repository root.
# This makes data paths reliable for all collaborators, regardless of where they open the notebook.

current_dir = os.getcwd()
repo_root = current_dir
while not os.path.exists(os.path.join(repo_root, '.git')):
    # Move up one directory
    parent_dir = os.path.dirname(repo_root)
    if parent_dir == repo_root: # Reached filesystem root, .git not found
        raise FileNotFoundError(
            "Could not find the .git directory. "
            "Please ensure you are running this code from within a Git repository."
        )
    repo_root = parent_dir

# Change the current working directory if it's not already the repo root
if os.getcwd() != repo_root:
    os.chdir(repo_root)
    print(f"Working directory set to: {os.getcwd()}") # Informative print for users


# --- Data Loading ---
# Path to the data file, relative to the repository root.
data_file_name = 'df_eng_customer_purchasing_features.csv'
data_file_path = os.path.join('data', 'processed', data_file_name)

try:
    df = pd.read_csv(data_file_path)
    print(f"Successfully loaded '{data_file_name}' into the DataFrame named df.")
    #print(df.head())
except FileNotFoundError:
    print(f"Error: The file '{data_file_name}' was not found at '{data_file_path}'.")
    print("Please ensure it exists in the 'data/processed/' folder relative to the repository root.")
except Exception as e:
    print(f"An error occurred during data loading: {e}")
# Out:
# Working directory set to: c:\Users\The Winner\DSI\customer_purchasing_behaviour
# Successfully loaded 'df_eng_customer_purchasing_features.csv' into the DataFrame named df.

# %% [markdown]
# Split the data between train portion and a holdout portion that will be used in another Notebook for validation and test

# %%
# Hold out 20% of the dataset (to become val + test in another Notebook, we will not use it here)
X_train, X_holdout, y_train, y_holdout = train_test_split(df.drop('purchase_amount', axis=1), df[['purchase_amount']], test_size=0.2, random_state=42)
df = pd.concat([X_train, y_train], axis=1)

# %% [markdown]
# Prepare data: scale numerical and encode categorical

# %%
# Preprocessing: Prepare Inputs

# Extract relevant columns
numerical_cols = ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'spend_per_purchase', 'spend_to_income_ratio', 'log_annual_income', 'log_purchase_frequency']
categorical_cols = ['region_grouped',  'is_high_value', 'is_champion']
target_col = 'purchase_amount'
target_col_log = 'log_purchase_amount'

# Filter to only use columns that actually exist
existing_numerical_cols = [col for col in numerical_cols if col in df.columns]
existing_categorical_cols = [col for col in categorical_cols if col in df.columns]

# Scale numerical features
scaler = StandardScaler()
X_num = scaler.fit_transform(df[existing_numerical_cols])

# Encode categorical feature
encoder = OneHotEncoder(sparse_output=False)
X_cat = encoder.fit_transform(df[existing_categorical_cols])

# Create DataFrames with distinct column names
num_df = pd.DataFrame(X_num, columns=existing_numerical_cols)
cat_columns = encoder.get_feature_names_out(existing_categorical_cols)
cat_df = pd.DataFrame(X_cat, columns=cat_columns)

# Combine safely
combined_df = pd.concat([num_df, cat_df], axis=1)

# Convert to torch tensor
X_train = torch.tensor(combined_df.values, dtype=torch.float32)

# Target variable
y_train = torch.tensor(df[target_col].values, dtype=torch.float32).view(-1, 1)
y_train_log = torch.tensor(df[target_col_log].values, dtype=torch.float32).view(-1, 1)

# Print dataset sizes and set max batch sizes
print(f"Dataset sizes:")
print(f"  Train (for KFold CV): {len(X_train)}")
print(f"  Holdout (not used): {len(X_holdout)}")
# Out:
# Dataset sizes:
#   Total: 238
#   Train (for KFold CV): 190
#   Holdout (not used): 48

# %% [markdown]
# Run Model and log it in MLflow

# %%
# ADDED: KFold setup
n_folds = 4
kfold = KFold(n_splits=n_folds, shuffle=True, random_state=42)

start_time = time.time()

os.chdir('./experiments/neural_networks') if not load_dotenv() else None
load_dotenv()
print(f"load_dotenv() returned: {load_dotenv()}")
mlflow.set_tracking_uri(os.getenv("MLFLOW_TRACKING_URI"))
mlflow.set_experiment(os.getenv("MLFLOW_EXPERIMENT_NAME"))

# --- MODIFIED: Changed lr and batch_size to initial values ---
lr = 0.005  # This will be the initial learning rate, will adapt during training
lr_min = 0.0005
batch_size = 16  # CHANGED: Initial batch size instead of fixed batch size
grad_threshold=0.01
batch_multiplier=2
lr_multiplier=0.8
width_1st_layer = 8
width_2nd_layer = 8
width_3rd_layer = 8
width_4th_layer = 8
width_output_layer = 1

# --- MODIFIED: Updated params to reflect adaptive nature ---
params = {
    "dataset": data_file_name,
    "width_1st_layer": width_1st_layer,
    "width_2nd_layer": width_2nd_layer,
    "width_3rd_layer": width_3rd_layer,
    "width_4th_layer": width_4th_layer,
    "width_output_layer": width_output_layer,
    "activation": "relu",
    "criterion": "Mean Squared Error (MSE) loss",
    "optimizer": "adam",
    "adaptive_batching_learning_rate": True,  # ADDED: Flag to indicate adaptive batching
    "initial_lr": lr,  # CHANGED: Renamed to initial_lr
    "initial_batch_size": batch_size,  # CHANGED: Renamed to initial_batch_size
    "max_batch_size": len(X_train),  # ADDED: Max batch size
    "grad_threshold": grad_threshold,
    "batch_multiplier": batch_multiplier,
    "lr_multiplier": lr_multiplier,
    "lr_min": lr_min
}

# ADDED: Store results for each fold
fold_results = {
    'val_mse': [], 'val_rmse': [], 'val_mae': [], 'val_mape': [], 'val_r2': [],
    'train_mse': [], 'train_rmse': [], 'train_mae': [], 'train_mape': [], 'train_r2': []
}

# ADDED: KFold cross-validation loop
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    print(f"\n--- Fold {fold + 1}/{n_folds} ---")
    
    # ADDED: Create fold-specific train/validation splits
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Make it reproducible (unchanged)
    SEED = 42
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Define the Neural Network Model (unchanged)
    class FeedforwardNN(nn.Module):
        def __init__(self, input_size):
            super(FeedforwardNN, self).__init__()
            self.layers = nn.Sequential(
                nn.Linear(input_size, width_1st_layer),
                nn.ReLU(),
                nn.Linear(width_1st_layer, width_2nd_layer),
                nn.ReLU(),
                nn.Linear(width_2nd_layer, width_3rd_layer),
                nn.ReLU(),
                nn.Linear(width_3rd_layer, width_4th_layer),
                nn.ReLU(),
                nn.Linear(width_4th_layer, width_output_layer)
            )

        def forward(self, x):
            return self.layers(x)

    model = FeedforwardNN(input_size=X_train_fold.shape[1])
    def init_weights(m):
        '''Make the weight initialization reproducible'''
        if isinstance(m, nn.Linear):
            torch.nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                torch.nn.init.constant_(m.bias, 0.01)
    model.apply(init_weights)      

    # Make GPU work (unchanged)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # MODIFIED: Move fold data to device
    X_train_fold = X_train_fold.to(device)
    y_train_fold = y_train_fold.to(device)
    X_val_fold = X_val_fold.to(device)
    y_val_fold = y_val_fold.to(device)
    
    # MODIFIED: Initialize adaptive batch trainer
    adaptive_trainer = GradientAdaptiveBatchingLearning(
        initial_batch_size=batch_size,
        initial_lr=lr,
        grad_threshold=grad_threshold,  # Tune this based on your loss scale
        batch_multiplier=batch_multiplier,  # Conservative increase
        lr_multiplier = lr_multiplier,
        lr_min = lr_min,
        max_batch_size=len(X_train_fold)  # CHANGED: Use actual training fold size
    )
    
    # MODIFIED: Create DataLoaders with fold data
    train_dataset = TensorDataset(X_train_fold, y_train_fold)
    val_dataset = TensorDataset(X_val_fold, y_val_fold)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Move model to device (unchanged)
    model = model.to(device)

    # Training with MSE & Logging RMSE, MAE (unchanged)
    def compute_rmse(predictions, targets):
        return torch.sqrt(F.mse_loss(predictions, targets))
    def compute_mae(predictions, targets):
        return torch.mean(torch.abs(predictions - targets))
    def compute_mape(predictions, targets):
        return torch.mean(torch.abs((predictions - targets) / targets) * 100)
    def compute_r2(predictions, targets):
        ss_res = torch.sum((targets - predictions) ** 2)
        ss_tot = torch.sum((targets - torch.mean(targets)) ** 2)
        return 1 - ss_res / ss_tot

    # --- MODIFIED: Training loop with adaptive batching ---
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), adaptive_trainer.current_lr)  # CHANGED: Use adaptive LR
    best_val_loss = float('inf')
    patience = 5000
    trigger_times = 0
    min_delta = 0# -0.01
    train_losses = []
    val_losses = []
    # ADDED: Track batch size and learning rate history
    batch_size_history = []
    lr_history = []

    progress = tqdm(range(10_001), desc=f"Fold {fold+1} Training")
    for epoch in progress:
        # Training phase with batches (unchanged structure)
        model.train()
        epoch_train_loss = 0.0
        num_train_batches = 0
        
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            output = model(batch_X)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            
            epoch_train_loss += loss.item()
            num_train_batches += 1
        
        avg_train_loss = epoch_train_loss / num_train_batches

        # Validation phase with batches (unchanged)
        model.eval()
        epoch_val_loss = 0.0
        num_val_batches = 0
        
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                val_output = model(batch_X)
                val_loss = criterion(val_output, batch_y)
                epoch_val_loss += val_loss.item()
                num_val_batches += 1
        
        avg_val_loss = epoch_val_loss / num_val_batches
        
        # --- ADDED: Adaptive batch size and learning rate update ---
        new_batch_size, new_lr = adaptive_trainer.update_params(avg_val_loss, epoch)
        
        # ADDED: Update optimizer learning rate if changed
        if new_lr != optimizer.param_groups[0]['lr']:
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
        
        # ADDED: Create new dataloader if batch size changed
        if new_batch_size != train_loader.batch_size:
            train_loader = DataLoader(train_dataset, batch_size=new_batch_size, shuffle=True)
            # Also update validation loader for consistency
            val_loader = DataLoader(val_dataset, batch_size=new_batch_size, shuffle=False)
        
        # ADDED: Track history
        batch_size_history.append(new_batch_size)
        lr_history.append(new_lr)
        
        # For progress display (modified to use fold data)
        with torch.no_grad():
            sample_output = model(X_train_fold[:new_batch_size])  # CHANGED: Use current batch size
            sample_rmse = compute_rmse(sample_output, y_train_fold[:new_batch_size])
            # MODIFIED: Show current batch size in progress
            progress.set_postfix({
                "Loss": avg_train_loss, 
                "RMSE": sample_rmse.item(),
                "BatchSize": new_batch_size,  # ADDED: Show current batch size
                "LR": f"{new_lr:.6f}"  # ADDED: Show current learning rate
            })
        
        # Save losses each epoch (unchanged)
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Early stopping logic (unchanged)
        if avg_val_loss + min_delta < best_val_loss:
            best_val_loss = avg_val_loss
            trigger_times = 0
        else:
            trigger_times += 1
            if trigger_times >= patience:
                print(f"\n⏹️ Early stopping at epoch {epoch} — no validation improvement after {patience} epochs.")
                
                model.eval()
                with torch.no_grad():
                    train_output = model(X_train_fold)
                    val_output = model(X_val_fold)
                    train_loss_final = criterion(train_output, y_train_fold)
                    val_loss_final = criterion(val_output, y_val_fold)
                    
                    rmse = compute_rmse(train_output, y_train_fold)
                    mae = compute_mae(train_output, y_train_fold)
                    r2 = compute_r2(train_output, y_train_fold)
                    val_rmse = compute_rmse(val_output, y_val_fold)
                    val_mae = compute_mae(val_output, y_val_fold)
                    val_r2 = compute_r2(val_output, y_val_fold)
                    
                print(f"Train → MSE = {train_loss_final.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
                print(f"Val   → MSE = {val_loss_final.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")
                break

        if epoch % 10_000 == 0:
            model.eval()
            with torch.no_grad():
                train_output = model(X_train_fold)
                val_output = model(X_val_fold)
                train_loss_full = criterion(train_output, y_train_fold)
                val_loss_full = criterion(val_output, y_val_fold)
                
                rmse = compute_rmse(train_output, y_train_fold)
                mae = compute_mae(train_output, y_train_fold)
                r2 = compute_r2(train_output, y_train_fold)
                val_rmse = compute_rmse(val_output, y_val_fold)
                val_mae = compute_mae(val_output, y_val_fold)
                val_r2 = compute_r2(val_output, y_val_fold)
                
            print(f"Epoch {epoch}:")
            print(f"Train → MSE = {train_loss_full.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
            print(f"Val   → MSE = {val_loss_full.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")

    # Metrics after all the epochs - training
    model.eval()
    with torch.no_grad():
        # Get final predictions on full datasets
        train_output = model(X_train_fold)
        val_output = model(X_val_fold)
        
        # Training metrics
        training_mse = criterion(train_output, y_train_fold)
        training_rmse = compute_rmse(train_output, y_train_fold)
        training_mae = compute_mae(train_output, y_train_fold)
        training_mape = compute_mape(train_output, y_train_fold)
        training_r2_score = compute_r2(train_output, y_train_fold)
    
        # Validation metrics
        val_mse = criterion(val_output, y_val_fold)
        val_rmse = compute_rmse(val_output, y_val_fold)
        val_mae = compute_mae(val_output, y_val_fold)
        val_mape = compute_mape(val_output, y_val_fold)
        val_r2_score = compute_r2(val_output, y_val_fold)
        
        print(f"\nFold {fold+1} Final Results:")
        print(f"Train → MSE = {training_mse.item():.4f}, RMSE = {training_rmse.item():.4f}, MAE = {training_mae.item():.4f}, R² Score = {training_r2_score.item():.4f}")
        print(f"Val   → MSE = {val_mse.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² Score = {val_r2_score.item():.4f}")

    # DELETED: Individual fold MLflow logging - only keeping CV summary

    # ADDED: Store fold results
    fold_results['train_mse'].append(training_mse.item())
    fold_results['train_rmse'].append(training_rmse.item())
    fold_results['train_mae'].append(training_mae.item())
    fold_results['train_mape'].append(training_mape.item())
    fold_results['train_r2'].append(training_r2_score.item())
    
    fold_results['val_mse'].append(val_mse.item())
    fold_results['val_rmse'].append(val_rmse.item())
    fold_results['val_mae'].append(val_mae.item())
    fold_results['val_mape'].append(val_mape.item())
    fold_results['val_r2'].append(val_r2_score.item())

    # --- ADDED: Enhanced plotting with adaptive batching info ---
    start = 100 
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves (existing plot)
    ax1.plot(range(start, len(train_losses)), train_losses[start:], label='Training Loss', color='blue')
    ax1.plot(range(start, len(val_losses)), val_losses[start:], label='Validation Loss', color='orange')
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.set_title(f"Loss Curves - Fold {fold+1}")
    ax1.legend()
    ax1.grid(True)
    
    # ADDED: Batch size evolution
    ax2.plot(batch_size_history, color='green')
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Batch Size")
    ax2.set_title(f"Batch Size Evolution - Fold {fold+1}")
    ax2.grid(True)
    
    # ADDED: Learning rate evolution
    ax3.plot(lr_history, color='red')
    ax3.set_xlabel("Epoch")
    ax3.set_ylabel("Learning Rate")
    ax3.set_title(f"Learning Rate Evolution - Fold {fold+1}")
    ax3.grid(True)
    
    # ADDED: Validation loss gradient (to visualize why batch size changed)
    if len(val_losses) > 50:
        val_gradients = np.diff(val_losses)
        ax4.plot(val_gradients[-min(10000, len(val_gradients)):], color='orange', alpha=0.7)
        ax4.axhline(y=adaptive_trainer.grad_threshold, color='red', linestyle='--', 
                    label=f'Threshold: {adaptive_trainer.grad_threshold}')
        ax4.axhline(y=-adaptive_trainer.grad_threshold, color='red', linestyle='--')
        ax4.set_xlabel("Epoch")
        ax4.set_ylabel("Validation Loss Gradient")
        ax4.set_title(f"Recent Validation Loss Gradient - Fold {fold+1}")
        ax4.legend()
        ax4.grid(True)
    
    plt.tight_layout()   
    # ADDED: Log this fold's plot to MLflow immediately
    plot_filename = f"fold_{fold+1}_training_plots.png"
    plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
    # after show, it deletes the plot
    plt.show()
    
    # Log to MLflow in a separate run for this fold
    fold_run_name = f"Fold_{fold+1}_lr{lr}_bs{batch_size}_w{width_1st_layer}x{width_2nd_layer}x{width_3rd_layer}x{width_4th_layer}"
    with mlflow.start_run(run_name=fold_run_name):
        # Log fold-specific parameters
        fold_params = params.copy()
        fold_params["fold"] = fold + 1
        fold_params["max_batch_size"] = len(X_train_fold)
        mlflow.log_params(fold_params)
        
        # Log the plot artifact
        mlflow.log_artifact(plot_filename)
        
    plt.close()  # Close to free memory
    os.remove(plot_filename)  # Clean up the file
    
    # ADDED: Print summary of adaptive batching
    print(f"\n📊 Adaptive Batching Summary - Fold {fold+1}:")
    print(f"  Initial batch size: {batch_size}")
    print(f"  Final batch size: {batch_size_history[-1]}")
    print(f"  Initial learning rate: {lr:.6f}")
    print(f"  Final learning rate: {lr_history[-1]:.6f}")
    print(f"  Number of batch size increases: {len(set(batch_size_history)) - 1}")

    # Clean memory in case we want to run this cell again without running the whole notebook
    # remove references to GPU objects 
    del model
    # Invoke garbage collector
    gc.collect()
    # Clear GPU cache
    torch.cuda.empty_cache()

# ADDED: Compute and log cross-validation summary statistics
print(f"\n{'='*60}")
print(f"Cross-Validation Summary")
print(f"{'='*60}")

cv_summary = {}
for metric_name, values in fold_results.items():
    mean_val = np.mean(values)
    std_val = np.std(values)
    cv_summary[f"{metric_name}_mean"] = mean_val
    cv_summary[f"{metric_name}_std"] = std_val
    print(f"{metric_name}: {mean_val:.4f} ± {std_val:.4f}")

# ADDED: Log cross-validation summary to MLflow
# ADDED: Set custom run name
run_name = f"KFold_CV_SUMMARY_lr{lr}_bs{batch_size}_w{width_1st_layer}x{width_2nd_layer}x{width_3rd_layer}x{width_4th_layer}_gt{grad_threshold}"
with mlflow.start_run(run_name=run_name):
    # Log hyperparameter configuration
    summary_params = params.copy()
    summary_params["n_folds"] = n_folds
    summary_params["cv_summary"] = True
    mlflow.log_params(summary_params)
    
    # Log all CV summary metrics
    for metric_name, metric_value in cv_summary.items():
        mlflow.log_metric(metric_name, round(metric_value, 4))

# Clean memory in case we want to run this cell again without running the whole notebook
# Invoke garbage collector
gc.collect()
# Clear GPU cache
torch.cuda.empty_cache()

end_time = time.time()
elapsed_time = end_time - start_time
print(f"\n⏳ Training completed in {elapsed_time:.2f} seconds.")
# Out:
# load_dotenv() returned: True
#
# --- Fold 1/4 ---
# Fold 1 Training:   0%|          | 0/10001 [00:00<?, ?it/s]
# Epoch 0:
# Train → MSE = 197932.6406, RMSE = 444.8962, MAE = 424.6166, R² = -10.7023
# Val   → MSE = 185898.9688, RMSE = 431.1600, MAE = 401.0001, R² = -6.7973
# Epoch 99: Gradient = 0.008147 < 0.01
#   → Increased batch size: 16 → 32
#   → Decreased learning rate: 0.005000 → 0.004000
# Epoch 138: Gradient = 0.002708 < 0.01
#   → Increased batch size: 32 → 64
#   → Decreased learning rate: 0.004000 → 0.003200
# Epoch 151: Gradient = -0.004651 < 0.01
#   → Increased batch size: 64 → 128
#   → Decreased learning rate: 0.003200 → 0.002560
# Epoch 209: Gradient = -0.003151 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.002560 → 0.002048
# Epoch 234: Gradient = 0.008023 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.002048 → 0.001638
# Epoch 247: Gradient = 0.005714 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001638 → 0.001311
# Epoch 257: Gradient = 0.006344 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001311 → 0.001049
# Epoch 270: Gradient = -0.009418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.001049 → 0.000839
# Epoch 280: Gradient = 0.002011 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000839 → 0.000671
# Epoch 290: Gradient = -0.003616 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000671 → 0.000537
# Epoch 300: Gradient = -0.000670 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 310: Gradient = -0.001503 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 320: Gradient = -0.001240 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 330: Gradient = -0.001205 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 340: Gradient = -0.001292 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 350: Gradient = -0.001138 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 360: Gradient = -0.001203 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 370: Gradient = -0.001183 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 380: Gradient = -0.001096 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 390: Gradient = -0.001177 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 400: Gradient = -0.001129 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 410: Gradient = -0.001091 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 420: Gradient = -0.001194 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 430: Gradient = -0.001119 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 440: Gradient = -0.001330 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 450: Gradient = -0.001257 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 460: Gradient = -0.001178 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 470: Gradient = -0.001095 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 480: Gradient = -0.001184 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 490: Gradient = -0.001190 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 500: Gradient = -0.001198 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 510: Gradient = -0.001254 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 520: Gradient = -0.001344 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 530: Gradient = -0.001287 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 540: Gradient = -0.001167 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 550: Gradient = -0.001227 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 560: Gradient = -0.001264 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 570: Gradient = -0.001245 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 580: Gradient = -0.001252 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 590: Gradient = -0.001197 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 600: Gradient = -0.001281 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 610: Gradient = -0.001333 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 620: Gradient = -0.001324 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 630: Gradient = -0.001314 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 640: Gradient = -0.001326 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 650: Gradient = -0.001332 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 660: Gradient = -0.001266 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 670: Gradient = -0.001251 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 680: Gradient = -0.001219 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 690: Gradient = -0.001193 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 700: Gradient = -0.001235 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 710: Gradient = -0.001250 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 720: Gradient = -0.001372 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 730: Gradient = -0.001580 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 740: Gradient = -0.001157 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 750: Gradient = -0.001282 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 760: Gradient = -0.001252 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 770: Gradient = -0.001255 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 780: Gradient = -0.001405 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 790: Gradient = -0.001327 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 800: Gradient = -0.001271 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 810: Gradient = -0.001201 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 820: Gradient = -0.001241 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 830: Gradient = -0.001338 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 840: Gradient = -0.001484 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 850: Gradient = -0.001395 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 860: Gradient = -0.001291 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 870: Gradient = -0.001207 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 880: Gradient = -0.001360 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 890: Gradient = -0.001405 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 900: Gradient = -0.001324 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 910: Gradient = -0.001260 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 920: Gradient = -0.001224 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 930: Gradient = -0.001473 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 940: Gradient = -0.001556 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 950: Gradient = -0.001211 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 960: Gradient = -0.001367 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 970: Gradient = -0.001177 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 980: Gradient = -0.001266 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 990: Gradient = -0.001544 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1000: Gradient = -0.001300 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1010: Gradient = -0.001456 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1020: Gradient = -0.001207 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1030: Gradient = -0.001418 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1040: Gradient = -0.001240 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1050: Gradient = -0.001431 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1060: Gradient = -0.001295 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1070: Gradient = -0.001502 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1080: Gradient = -0.001395 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1090: Gradient = -0.001308 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1100: Gradient = -0.001437 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1110: Gradient = -0.001289 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1120: Gradient = -0.001532 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1130: Gradient = -0.001348 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1140: Gradient = -0.001465 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1150: Gradient = -0.001420 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1160: Gradient = -0.001425 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1170: Gradient = -0.001506 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1180: Gradient = -0.002677 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1194: Gradient = -0.009947 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1204: Gradient = -0.008500 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1225: Gradient = -0.009995 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1235: Gradient = -0.004016 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1245: Gradient = -0.003599 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1255: Gradient = 0.001450 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1265: Gradient = -0.004237 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1275: Gradient = 0.003712 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1285: Gradient = -0.001331 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1295: Gradient = -0.001080 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1305: Gradient = -0.002793 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1315: Gradient = -0.002057 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1325: Gradient = -0.001741 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1335: Gradient = -0.001206 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1345: Gradient = -0.001419 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1355: Gradient = -0.002051 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1365: Gradient = -0.001264 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1375: Gradient = -0.002056 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1385: Gradient = -0.001272 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1395: Gradient = -0.001726 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1405: Gradient = -0.001256 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1415: Gradient = -0.001935 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1425: Gradient = -0.001778 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1435: Gradient = -0.001720 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1445: Gradient = -0.001446 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1455: Gradient = -0.001953 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1465: Gradient = -0.001283 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1475: Gradient = -0.001444 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1485: Gradient = -0.001832 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1495: Gradient = -0.001844 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1505: Gradient = -0.000568 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1515: Gradient = -0.000316 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1525: Gradient = -0.001684 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1535: Gradient = -0.001808 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1545: Gradient = -0.001198 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1555: Gradient = -0.001485 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1565: Gradient = -0.000618 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1575: Gradient = -0.001750 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1585: Gradient = -0.001312 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1595: Gradient = -0.001325 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1605: Gradient = -0.001506 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1615: Gradient = -0.001351 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1625: Gradient = -0.001190 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1635: Gradient = -0.001467 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1645: Gradient = -0.001391 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1655: Gradient = -0.001054 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1665: Gradient = -0.002045 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1675: Gradient = -0.003127 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1685: Gradient = -0.001225 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1695: Gradient = -0.000236 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1705: Gradient = -0.000098 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1715: Gradient = -0.001183 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1725: Gradient = -0.001121 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1735: Gradient = -0.000947 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1745: Gradient = -0.000973 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1755: Gradient = -0.001181 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1765: Gradient = -0.001201 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1775: Gradient = -0.001662 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1785: Gradient = -0.000658 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1795: Gradient = -0.001689 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1805: Gradient = -0.001684 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1815: Gradient = -0.001837 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1825: Gradient = -0.001309 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1835: Gradient = -0.000578 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1845: Gradient = -0.002375 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1855: Gradient = -0.000330 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1865: Gradient = -0.001977 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1875: Gradient = -0.000538 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1885: Gradient = -0.000840 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1895: Gradient = -0.001290 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1905: Gradient = -0.001341 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1915: Gradient = -0.001062 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1925: Gradient = -0.000520 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1935: Gradient = -0.001454 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1945: Gradient = -0.001468 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1955: Gradient = -0.000995 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1965: Gradient = -0.002476 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1975: Gradient = -0.001438 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1985: Gradient = -0.000521 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 1995: Gradient = -0.001798 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2005: Gradient = -0.000903 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2015: Gradient = -0.001380 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2025: Gradient = -0.001529 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2035: Gradient = -0.001208 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2045: Gradient = -0.001179 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2055: Gradient = -0.001328 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2065: Gradient = -0.001202 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2075: Gradient = -0.000960 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2085: Gradient = -0.001182 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2095: Gradient = -0.001806 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2105: Gradient = -0.001768 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2115: Gradient = -0.001040 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2125: Gradient = -0.000585 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2135: Gradient = 0.000170 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2145: Gradient = -0.000474 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2155: Gradient = -0.001610 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2165: Gradient = -0.001225 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2175: Gradient = -0.000878 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2185: Gradient = -0.001649 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2195: Gradient = -0.000819 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2205: Gradient = 0.000199 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2215: Gradient = -0.001042 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2225: Gradient = -0.001614 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2235: Gradient = -0.000714 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2245: Gradient = -0.001127 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2255: Gradient = -0.001477 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2265: Gradient = -0.001837 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2275: Gradient = -0.002166 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2285: Gradient = -0.002488 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2295: Gradient = -0.001588 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2305: Gradient = -0.002368 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2315: Gradient = -0.001612 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2325: Gradient = 0.000335 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2335: Gradient = -0.001205 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2345: Gradient = -0.001602 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2355: Gradient = -0.001531 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2365: Gradient = -0.002377 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2375: Gradient = -0.001774 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2385: Gradient = -0.002524 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2395: Gradient = -0.002704 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2405: Gradient = -0.000265 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2415: Gradient = 0.000405 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2425: Gradient = -0.001262 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2435: Gradient = -0.001957 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2445: Gradient = -0.000894 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2455: Gradient = -0.000231 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2465: Gradient = -0.001275 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2475: Gradient = -0.001490 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2485: Gradient = -0.000494 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2495: Gradient = -0.001164 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2505: Gradient = -0.002075 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2515: Gradient = -0.001220 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2525: Gradient = -0.001107 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2535: Gradient = -0.001596 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2545: Gradient = -0.002877 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2555: Gradient = -0.002003 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2565: Gradient = -0.000735 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2575: Gradient = -0.000994 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2585: Gradient = -0.001699 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2595: Gradient = -0.001771 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2605: Gradient = -0.000726 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2615: Gradient = -0.000779 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2625: Gradient = -0.002175 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2635: Gradient = -0.002890 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2645: Gradient = -0.001208 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2655: Gradient = -0.001180 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2665: Gradient = -0.000429 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2675: Gradient = 0.000281 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2685: Gradient = -0.000304 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2695: Gradient = -0.001002 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2705: Gradient = -0.002290 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2715: Gradient = -0.001378 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2725: Gradient = -0.000886 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2735: Gradient = -0.001594 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2745: Gradient = -0.001478 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2755: Gradient = -0.001046 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2765: Gradient = -0.001734 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2775: Gradient = -0.001309 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2785: Gradient = -0.000892 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2795: Gradient = -0.001827 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2805: Gradient = -0.001343 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2815: Gradient = -0.000050 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2825: Gradient = -0.000793 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2835: Gradient = -0.000569 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2845: Gradient = -0.001087 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2855: Gradient = -0.001618 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2865: Gradient = -0.001099 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2875: Gradient = -0.001724 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2885: Gradient = -0.001684 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2895: Gradient = -0.001721 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2905: Gradient = -0.001394 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2915: Gradient = -0.001691 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2925: Gradient = -0.001381 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2935: Gradient = -0.001273 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2945: Gradient = -0.001847 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2955: Gradient = -0.000299 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2965: Gradient = -0.000884 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2975: Gradient = -0.000362 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2985: Gradient = -0.000860 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 2995: Gradient = -0.001350 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3005: Gradient = -0.000596 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3015: Gradient = -0.001882 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3025: Gradient = -0.001756 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3035: Gradient = -0.000386 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3045: Gradient = -0.001090 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3055: Gradient = -0.001801 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3065: Gradient = -0.001041 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3075: Gradient = -0.001920 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3085: Gradient = -0.003268 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3095: Gradient = -0.002290 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3105: Gradient = -0.003711 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3115: Gradient = -0.003047 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3125: Gradient = -0.001896 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3135: Gradient = -0.002491 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3145: Gradient = -0.002307 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3155: Gradient = -0.002251 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3165: Gradient = -0.002045 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3175: Gradient = 0.000011 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3185: Gradient = -0.000239 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3195: Gradient = -0.001778 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3205: Gradient = -0.001291 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3215: Gradient = -0.001840 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3225: Gradient = -0.002777 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3235: Gradient = -0.001892 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3245: Gradient = -0.002114 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3255: Gradient = -0.003095 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3265: Gradient = -0.001187 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3275: Gradient = -0.001391 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3285: Gradient = -0.000881 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3295: Gradient = -0.001506 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3305: Gradient = -0.000807 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3315: Gradient = -0.001847 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3325: Gradient = -0.001229 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3335: Gradient = -0.002195 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3345: Gradient = -0.001619 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3355: Gradient = -0.001472 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3365: Gradient = -0.001891 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3375: Gradient = -0.000807 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3385: Gradient = -0.001126 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3395: Gradient = -0.001264 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3405: Gradient = -0.001817 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3415: Gradient = -0.001715 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3425: Gradient = -0.001074 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3435: Gradient = -0.000785 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3445: Gradient = -0.001417 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3455: Gradient = -0.001168 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3465: Gradient = -0.001142 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3475: Gradient = -0.001103 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3485: Gradient = -0.001082 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3495: Gradient = -0.001673 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3505: Gradient = -0.001249 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3515: Gradient = -0.001520 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3525: Gradient = -0.001095 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3535: Gradient = -0.000694 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3545: Gradient = -0.001978 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3555: Gradient = -0.001258 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3565: Gradient = -0.000782 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3575: Gradient = -0.001554 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3585: Gradient = -0.001226 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3595: Gradient = -0.000892 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3605: Gradient = -0.001396 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3615: Gradient = -0.001328 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3625: Gradient = 0.000552 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3635: Gradient = -0.001185 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3645: Gradient = -0.002151 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3655: Gradient = -0.002008 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3665: Gradient = -0.002679 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3675: Gradient = -0.001157 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3685: Gradient = -0.002113 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3695: Gradient = -0.002653 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3705: Gradient = -0.001702 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3715: Gradient = -0.001725 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3725: Gradient = -0.001127 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3735: Gradient = -0.001204 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3745: Gradient = -0.000896 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3755: Gradient = -0.000997 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3765: Gradient = -0.001593 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3775: Gradient = -0.002682 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3785: Gradient = -0.001583 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3795: Gradient = -0.001002 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3805: Gradient = 0.000082 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3815: Gradient = -0.001102 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3825: Gradient = -0.001079 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3835: Gradient = -0.002078 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3845: Gradient = -0.002385 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3855: Gradient = -0.001848 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3865: Gradient = -0.001471 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3875: Gradient = -0.000203 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3885: Gradient = -0.000566 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3895: Gradient = -0.001034 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3905: Gradient = -0.000411 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3915: Gradient = -0.000447 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3925: Gradient = -0.000288 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3935: Gradient = -0.001125 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3945: Gradient = -0.001652 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3955: Gradient = -0.001196 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3965: Gradient = -0.001149 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3975: Gradient = -0.001281 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3985: Gradient = -0.002014 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 3995: Gradient = -0.001529 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4005: Gradient = -0.001111 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4015: Gradient = -0.000789 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4025: Gradient = -0.001546 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4035: Gradient = -0.001816 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4045: Gradient = -0.001350 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4055: Gradient = -0.001466 < 0.01
#   → Increased batch size: 71 → 142
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 4065: Gradient = -0.000733 < 0.01
#   → Increased batch size: 71 → 142
# ...
# Epoch 8730: Gradient = -0.001060 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8740: Gradient = 0.001510 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8754: Gradient = 0.005932 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8764: Gradient = 0.003667 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8778: Gradient = -0.000741 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8790: Gradient = -0.007131 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8800: Gradient = -0.002501 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8810: Gradient = 0.003363 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8820: Gradient = -0.002147 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8830: Gradient = 0.000854 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8840: Gradient = -0.000298 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8850: Gradient = 0.000255 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8860: Gradient = -0.000284 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8870: Gradient = 0.000129 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8880: Gradient = 0.000022 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8890: Gradient = -0.000078 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8900: Gradient = 0.000194 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8910: Gradient = 0.000684 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8920: Gradient = 0.006291 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8943: Gradient = 0.000621 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8953: Gradient = 0.001409 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8965: Gradient = -0.003299 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8975: Gradient = -0.003499 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8985: Gradient = 0.002567 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 8995: Gradient = -0.002719 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9005: Gradient = 0.001088 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9015: Gradient = -0.000500 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9025: Gradient = 0.000014 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9035: Gradient = 0.000200 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9045: Gradient = 0.000008 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9055: Gradient = -0.000001 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9065: Gradient = -0.000171 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9075: Gradient = -0.000839 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9085: Gradient = 0.001458 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9095: Gradient = -0.008286 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9106: Gradient = -0.005227 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9116: Gradient = -0.001675 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9130: Gradient = -0.002286 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9140: Gradient = -0.008193 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9150: Gradient = 0.004473 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9160: Gradient = -0.000617 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9170: Gradient = -0.000696 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9180: Gradient = 0.000570 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9190: Gradient = -0.000513 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9200: Gradient = 0.000028 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9210: Gradient = -0.000026 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9220: Gradient = -0.000271 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9230: Gradient = -0.000096 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9240: Gradient = -0.000073 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9250: Gradient = 0.000051 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9260: Gradient = 0.000370 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9270: Gradient = 0.003035 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9299: Gradient = 0.005925 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9311: Gradient = -0.009130 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9324: Gradient = 0.009323 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9334: Gradient = 0.005201 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9344: Gradient = -0.001795 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9354: Gradient = -0.001963 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9364: Gradient = 0.001483 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9374: Gradient = -0.000476 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9384: Gradient = -0.000031 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9394: Gradient = 0.000117 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9404: Gradient = -0.000061 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9414: Gradient = 0.000094 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9424: Gradient = -0.000036 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9434: Gradient = 0.000002 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9444: Gradient = -0.000043 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9454: Gradient = -0.000106 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9464: Gradient = -0.000412 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9474: Gradient = -0.001278 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9490: Gradient = 0.006469 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9506: Gradient = 0.003607 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9517: Gradient = 0.003846 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9527: Gradient = -0.009690 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9537: Gradient = 0.004658 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9547: Gradient = -0.000924 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9557: Gradient = 0.000697 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9567: Gradient = -0.000662 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9577: Gradient = 0.000328 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9587: Gradient = -0.000402 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9597: Gradient = -0.000211 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9607: Gradient = -0.000107 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9617: Gradient = -0.000260 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9627: Gradient = -0.000820 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9637: Gradient = 0.002677 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9647: Gradient = 0.001221 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9663: Gradient = 0.003973 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9674: Gradient = 0.006890 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9684: Gradient = -0.006739 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9694: Gradient = 0.002075 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9704: Gradient = 0.000317 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9714: Gradient = -0.000647 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9724: Gradient = 0.000322 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9734: Gradient = 0.000134 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9744: Gradient = -0.000338 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9754: Gradient = 0.000052 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9764: Gradient = 0.000119 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9774: Gradient = 0.000219 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9784: Gradient = 0.000977 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9795: Gradient = 0.001584 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9815: Gradient = 0.008742 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9825: Gradient = -0.003752 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9837: Gradient = -0.005702 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9847: Gradient = 0.003405 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9857: Gradient = -0.000120 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9867: Gradient = 0.000141 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9877: Gradient = -0.000353 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9887: Gradient = 0.000560 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9897: Gradient = -0.000380 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9907: Gradient = -0.000050 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9917: Gradient = -0.000046 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9927: Gradient = -0.000493 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9937: Gradient = -0.001081 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9952: Gradient = 0.009780 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9962: Gradient = 0.000998 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9973: Gradient = 0.000311 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9985: Gradient = -0.003996 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 9995: Gradient = 0.003350 < 0.01
#   → Increased batch size: 71 → 143
#   → Decreased learning rate: 0.000625 → 0.000500
# Epoch 10000:
# Train → MSE = 0.0046, RMSE = 0.0682, MAE = 0.0339, R² = 1.0000
# Val   → MSE = 0.2242, RMSE = 0.4735, MAE = 0.1737, R² = 1.0000
#
# Fold 4 Final Results:
# Train → MSE = 0.0046, RMSE = 0.0682, MAE = 0.0339, R² Score = 1.0000
# Val   → MSE = 0.2242, RMSE = 0.4735, MAE = 0.1737, R² Score = 1.0000
# 🏃 View run Fold_4_lr0.005_bs16_w32x32x32x32 at: http://localhost:5000/#/experiments/419688249660477162/runs/251ef68f73c746c195c9e1f95bfbd6f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/419688249660477162
#
# 📊 Adaptive Batching Summary - Fold 4:
#   Initial batch size: 16
#   Final batch size: 143
#   Initial learning rate: 0.005000
#   Final learning rate: 0.000500
#   Number of batch size increases: 4
#
# ============================================================
# Cross-Validation Summary
# ============================================================
# val_mse: 2.4223 ± 2.0648
# val_rmse: 1.3784 ± 0.7226
# val_mae: 0.4481 ± 0.1920
# val_mape: 0.1630 ± 0.0740
# val_r2: 0.9999 ± 0.0001
# train_mse: 0.0415 ± 0.0619
# train_rmse: 0.1532 ± 0.1343
# train_mae: 0.1124 ± 0.1373
# train_mape: 0.0264 ± 0.0304
# train_r2: 1.0000 ± 0.0000
# 🏃 View run KFold_CV_SUMMARY_lr0.005_bs16_w32x32x32x32_gt0.01 at: http://localhost:5000/#/experiments/419688249660477162/runs/5ae577ddfe2d4b3790e092fb2402eed8
# 🧪 View experiment at: http://localhost:5000/#/experiments/419688249660477162
#
# ⏳ Training completed in 465.60 seconds.

# %%
# print(f"DEBUG: fold_results = {fold_results}")

# %%
# cv_summary = {}
# for metric_name, values in fold_results.items():
#     mean_val = np.mean(values)
#     std_val = np.std(values)
#     cv_summary[f"{metric_name}_mean"] = mean_val
#     cv_summary[f"{metric_name}_std"] = std_val
#     print(f"{metric_name}: {mean_val:.4f} ± {std_val:.4f}")
