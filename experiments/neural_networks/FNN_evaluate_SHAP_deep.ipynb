# %% [markdown]
# **Feedforward Neural Network (FNN)**

# %% [markdown]
# Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import gc
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import os
import pandas as pd
import random
import time
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature
import shap

# %% [markdown]
# Classes / Functions used below

# %%
# Gradient-Based Adaptive Batch Size Class
class GradientAdaptiveBatchingLearning:
    def __init__(self, initial_batch_size=16, initial_lr=0.001, 
                 grad_threshold=0.01, batch_multiplier=1.4, lr_multiplier=0.8, lr_min=0.0005, max_batch_size=142):
        self.current_batch_size = initial_batch_size
        self.current_lr = initial_lr
        self.grad_threshold = grad_threshold
        self.batch_multiplier = batch_multiplier
        self.lr_multiplier = lr_multiplier
        self.lr_min = lr_min
        self.max_batch_size = max_batch_size  # Will be set dynamically to len(X_train)
        self.loss_history = []
        self.update_count = 0
        
    def update_params(self, current_loss, epoch):
        self.loss_history.append(current_loss)
        
        # Need at least 5 epochs of history for gradient calculation
        if len(self.loss_history) >= 5:
            # Calculate gradient (first derivative) over recent losses
            recent_losses = self.loss_history[-5:]
            gradient = np.mean(np.diff(recent_losses))
            
            # Additional stability check: don't update too frequently
            epochs_since_update = len(self.loss_history) - self.update_count
            
            # If gradient is small (slow improvement) and enough time passed
            if abs(gradient) < self.grad_threshold and epochs_since_update >= 10:
                new_batch_size = min(
                    int(self.current_batch_size * self.batch_multiplier), 
                    self.max_batch_size
                )
                # Decrease learning rate when increasing batch size
                lr_scaling = self.lr_multiplier  # self.current_batch_size / new_batch_size
                self.current_lr = max(
                    self.current_lr*lr_scaling, 
                    self.lr_min
                )
                self.current_batch_size = new_batch_size
                self.update_count = len(self.loss_history)
                
                print(f"Epoch {epoch}: Gradient = {gradient:.6f} < {self.grad_threshold}")
                print(f"  → Increased batch size: {int(self.current_batch_size/self.batch_multiplier)} → {self.current_batch_size}")
                print(f"  → Decreased learning rate: {self.current_lr/lr_scaling:.6f} → {self.current_lr:.6f}")
                    
        return self.current_batch_size, self.current_lr

# %% [markdown]
# Load csv into df

# %%
# --- Ensure consistent working directory for data loading ---
# This block dynamically sets the current working directory to the Git repository root.
# This makes data paths reliable for all collaborators, regardless of where they open the notebook.

current_dir = os.getcwd()
repo_root = current_dir
while not os.path.exists(os.path.join(repo_root, '.git')):
    # Move up one directory
    parent_dir = os.path.dirname(repo_root)
    if parent_dir == repo_root: # Reached filesystem root, .git not found
        raise FileNotFoundError(
            "Could not find the .git directory. "
            "Please ensure you are running this code from within a Git repository."
        )
    repo_root = parent_dir

# Change the current working directory if it's not already the repo root
if os.getcwd() != repo_root:
    os.chdir(repo_root)
    print(f"Working directory set to: {os.getcwd()}") # Informative print for users


# --- Data Loading ---
# Path to the data file, relative to the repository root.
data_file_name = 'df_eng_customer_purchasing_features.csv'
data_file_path = os.path.join('data', 'processed', data_file_name)

try:
    df = pd.read_csv(data_file_path)
    print(f"Successfully loaded '{data_file_name}' into the DataFrame named df.")
    #print(df.head())
except FileNotFoundError:
    print(f"Error: The file '{data_file_name}' was not found at '{data_file_path}'.")
    print("Please ensure it exists in the 'data/processed/' folder relative to the repository root.")
except Exception as e:
    print(f"An error occurred during data loading: {e}")
# Out:
# Working directory set to: c:\Users\The Winner\DSI\customer_purchasing_behaviour
# Successfully loaded 'df_eng_customer_purchasing_features.csv' into the DataFrame named df.

# %% [markdown]
# Split the data between train portion and a holdout portion, split holdout for validation and test

# %%
# Step 1: Hold out 20% of the dataset (to become val + test)
X_train, X_holdout, y_train, y_holdout = train_test_split(df.drop(['purchase_amount', 'log_purchase_amount'], axis=1), df[['purchase_amount', 'log_purchase_amount']], test_size=0.2, random_state=42)
df_train = pd.concat([X_train, y_train], axis=1)
# Step 2: Split holdout into 10% validation and 10% test
X_val, X_test, y_val, y_test = train_test_split(X_holdout, y_holdout, test_size=0.5, random_state=42)
df_val = pd.concat([X_val, y_val], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %% [markdown]
# Prepare TRAIN data: scale numerical and encode categorical

# %%
df = df_train.copy() 

# Preprocessing: Prepare Inputs

# Extract relevant columns
numerical_cols = ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'log_annual_income', 'log_purchase_frequency']
categorical_cols = ['region_grouped']
target_col = 'purchase_amount'
target_col_log = 'log_purchase_amount'

# Filter to only use columns that actually exist
existing_numerical_cols = [col for col in numerical_cols if col in df.columns]
existing_categorical_cols = [col for col in categorical_cols if col in df.columns]

# Scale numerical features
scaler = StandardScaler()
X_num = scaler.fit_transform(df[existing_numerical_cols])

# Encode categorical feature
encoder = OneHotEncoder(sparse_output=False)
X_cat = encoder.fit_transform(df[existing_categorical_cols])

# Create DataFrames with distinct column names
num_df = pd.DataFrame(X_num, columns=existing_numerical_cols)
cat_columns = encoder.get_feature_names_out(existing_categorical_cols)
cat_df = pd.DataFrame(X_cat, columns=cat_columns)

# Combine safely
combined_df = pd.concat([num_df, cat_df], axis=1)

# Convert to torch tensor
X_train = torch.tensor(combined_df.values, dtype=torch.float32)

# Target variable
y_train = torch.tensor(df[target_col].values, dtype=torch.float32).view(-1, 1)
y_train_log = torch.tensor(df[target_col_log].values, dtype=torch.float32).view(-1, 1)

# %% [markdown]
# Prepare VAL data: scale numerical and encode categorical

# %%
df = df_val.copy() 

# Preprocessing: Prepare Inputs

# Extract relevant columns
numerical_cols = ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'log_annual_income', 'log_purchase_frequency']
categorical_cols = ['region_grouped']
target_col = 'purchase_amount'
target_col_log = 'log_purchase_amount'

# Filter to only use columns that actually exist
existing_numerical_cols = [col for col in numerical_cols if col in df.columns]
existing_categorical_cols = [col for col in categorical_cols if col in df.columns]

# Scale numerical features
X_num = scaler.transform(df[existing_numerical_cols])

# Encode categorical feature
X_cat = encoder.transform(df[existing_categorical_cols])

# Create DataFrames with distinct column names
num_df = pd.DataFrame(X_num, columns=existing_numerical_cols)
cat_columns = encoder.get_feature_names_out(existing_categorical_cols)
cat_df = pd.DataFrame(X_cat, columns=cat_columns)

# Combine safely
combined_df = pd.concat([num_df, cat_df], axis=1)

# Convert to torch tensor
X_val = torch.tensor(combined_df.values, dtype=torch.float32)

# Target variable
y_val = torch.tensor(df[target_col].values, dtype=torch.float32).view(-1, 1)
y_val_log = torch.tensor(df[target_col_log].values, dtype=torch.float32).view(-1, 1)

# %% [markdown]
# Prepare TEST data: scale numerical and encode categorical

# %%
df = df_test.copy() 

# Preprocessing: Prepare Inputs

# Extract relevant columns
numerical_cols = ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'log_annual_income', 'log_purchase_frequency']
categorical_cols = ['region_grouped']
target_col = 'purchase_amount'
target_col_log = 'log_purchase_amount'

# Filter to only use columns that actually exist
existing_numerical_cols = [col for col in numerical_cols if col in df.columns]
existing_categorical_cols = [col for col in categorical_cols if col in df.columns]

# Scale numerical features
X_num = scaler.transform(df[existing_numerical_cols])

# Encode categorical feature
X_cat = encoder.transform(df[existing_categorical_cols])

# Create DataFrames with distinct column names
num_df = pd.DataFrame(X_num, columns=existing_numerical_cols)
cat_columns = encoder.get_feature_names_out(existing_categorical_cols)
cat_df = pd.DataFrame(X_cat, columns=cat_columns)

# Combine safely
combined_df = pd.concat([num_df, cat_df], axis=1)

# Convert to torch tensor
X_test = torch.tensor(combined_df.values, dtype=torch.float32)

# Target variable
y_test = torch.tensor(df[target_col].values, dtype=torch.float32).view(-1, 1)
y_test_log = torch.tensor(df[target_col_log].values, dtype=torch.float32).view(-1, 1)

# %%
# Print dataset sizes and set max batch sizes
print(f"Dataset sizes:")
print(f"  Train: {len(X_train), len(y_train), X_train.shape, y_train.shape} (will be max batch size)")
print(f"  Validation: {len(X_val), len(y_val), X_val.shape, y_val.shape}")
print(f"  Test: {len(X_test), len(y_test), X_test.shape, y_test.shape}")
# Out:
# Dataset sizes:
#   Train: (190, 190, torch.Size([190, 11]), torch.Size([190, 1])) (will be max batch size)
#   Validation: (24, 24, torch.Size([24, 11]), torch.Size([24, 1]))
#   Test: (24, 24, torch.Size([24, 11]), torch.Size([24, 1]))

# %% [markdown]
# Functions will assist SHAP at the end

# %%
# SHAP functions

def explain_model_with_shap(model, X_train, X_test, feature_names, device, num_background=100, num_explain=20):
    """
    Generate SHAP explanations for the trained neural network
    
    Args:
        model: Trained PyTorch model
        X_train: Training data (for background distribution)
        X_test: Test data (to explain)
        feature_names: List of feature names
        device: PyTorch device (cuda/cpu)
        num_background: Number of background samples for SHAP
        num_explain: Number of test samples to explain
    """
    print("🔍 Generating SHAP explanations...")
    
    # Set model to evaluation mode
    model.eval()
    
    # Select background dataset (subset of training data)
    # SHAP needs this to establish baseline/expected values
    background_indices = np.random.choice(len(X_train), size=min(num_background, len(X_train)), replace=False)
    background_data = X_train[background_indices].cpu().numpy()
    
    # Select test samples to explain
    explain_indices = np.random.choice(len(X_test), size=min(num_explain, len(X_test)), replace=False)
    test_samples = X_test[explain_indices].cpu().numpy()
    
    # Create SHAP explainer
    # DeepExplainer is designed for neural networks
    explainer = shap.DeepExplainer(model, torch.FloatTensor(background_data).to(device))
    
    # Calculate SHAP values
    shap_values = explainer.shap_values(torch.FloatTensor(test_samples).to(device))
    
    # Convert to numpy if it's a tensor
    if isinstance(shap_values, torch.Tensor):
        shap_values = shap_values.cpu().numpy()
    elif isinstance(shap_values, list) and len(shap_values) == 1:
        # For regression, SHAP sometimes returns a list with one element
        shap_values = shap_values[0]
    
    print(f"✅ SHAP values calculated for {len(test_samples)} samples")
    print(f"   SHAP values shape: {shap_values.shape}")
    
    return explainer, shap_values, test_samples, background_data

def create_shap_visualizations(shap_values, test_samples, background_data, feature_names):
    """
    Create various SHAP visualizations and save them
    """
    print("📊 Creating SHAP visualizations...")
    
    # 1. Summary plot (bar chart of feature importance)
    plt.figure(figsize=(10, 6))
    shap.summary_plot(shap_values, test_samples, feature_names=feature_names, plot_type="bar", show=False)
    plt.title("SHAP Feature Importance Summary")
    plt.tight_layout()
    plt.savefig("shap_feature_importance.png", dpi=300, bbox_inches='tight')
    mlflow.log_artifact("shap_feature_importance.png")
    plt.show()
    
    # 2. Summary plot (beeswarm plot showing impact and value distribution)
    plt.figure(figsize=(10, 8))
    shap.summary_plot(shap_values, test_samples, feature_names=feature_names, show=False)
    plt.title("SHAP Summary Plot (Feature Impact)")
    plt.tight_layout()
    plt.savefig("shap_summary_beeswarm.png", dpi=300, bbox_inches='tight')
    mlflow.log_artifact("shap_summary_beeswarm.png")
    plt.show()
    
    # 3. Waterfall plot for first test sample (shows prediction breakdown)
    if len(test_samples) > 0:
        plt.figure(figsize=(10, 6))
        # Fix: Handle 2D output from regression model
        if shap_values.ndim == 3:  # Shape: (samples, features, outputs)
            sample_shap = shap_values[0, :, 0]  # First sample, all features, first output
            base_value = np.mean(shap_values[:, :, 0])
        elif shap_values.ndim == 2:  # Shape: (samples, features)
            sample_shap = shap_values[0, :]  # First sample, all features
            base_value = np.mean(shap_values)
        else:
            sample_shap = shap_values[0]
            base_value = np.mean(shap_values)
            
        shap.waterfall_plot(
            shap.Explanation(
                values=sample_shap, 
                base_values=base_value, 
                data=test_samples[0],
                feature_names=feature_names
            ),
            show=False
        )
        plt.title("SHAP Waterfall Plot (First Test Sample)")
        plt.tight_layout()
        plt.savefig("shap_waterfall_sample1.png", dpi=300, bbox_inches='tight')
        mlflow.log_artifact("shap_waterfall_sample1.png")
        plt.show()
    
    # 4. Force plot for first few samples (if less than 5 samples)
    if len(test_samples) <= 5:
        for i in range(len(test_samples)):
            plt.figure(figsize=(12, 3))
            # Fix: Handle 2D output from regression model
            if shap_values.ndim == 3:  # Shape: (samples, features, outputs)
                sample_shap = shap_values[i, :, 0]  # ith sample, all features, first output
                base_value = np.mean(shap_values[:, :, 0])
            elif shap_values.ndim == 2:  # Shape: (samples, features)
                sample_shap = shap_values[i, :]  # ith sample, all features
                base_value = np.mean(shap_values)
            else:
                sample_shap = shap_values[i]
                base_value = np.mean(shap_values)
                
            shap.force_plot(
                base_value=base_value,
                shap_values=sample_shap,
                features=test_samples[i],
                feature_names=feature_names,
                matplotlib=True,
                show=False
            )
            plt.title(f"SHAP Force Plot - Sample {i+1}")
            plt.tight_layout()
            plt.savefig(f"shap_force_plot_sample_{i+1}.png", dpi=300, bbox_inches='tight')
            mlflow.log_artifact(f"shap_force_plot_sample_{i+1}.png")
            plt.show()

def analyze_feature_importance(shap_values, feature_names):
    """
    Analyze and log feature importance metrics
    """
    # Handle different SHAP value shapes from regression models
    if shap_values.ndim == 3:  # Shape: (samples, features, outputs)
        # For regression, take the first (and only) output
        shap_vals_2d = shap_values[:, :, 0]
    elif shap_values.ndim == 2:  # Shape: (samples, features)
        shap_vals_2d = shap_values
    else:
        shap_vals_2d = shap_values
    
    # Calculate mean absolute SHAP values for each feature
    mean_abs_shap = np.mean(np.abs(shap_vals_2d), axis=0)
    
    # Create feature importance ranking
    feature_importance = list(zip(feature_names, mean_abs_shap))
    feature_importance.sort(key=lambda x: x[1], reverse=True)
    
    print("\n🏆 Feature Importance Ranking (by mean |SHAP value|):")
    for i, (feature, importance) in enumerate(feature_importance, 1):
        print(f"  {i:2d}. {feature:25s}: {importance:.4f}")
        # Log to MLflow
        mlflow.log_metric(f"shap_importance_{feature}", round(importance, 4))
    
    # Log top 3 most important features
    mlflow.log_param("most_important_feature", feature_importance[0][0])
    mlflow.log_param("second_most_important_feature", feature_importance[1][0])
    mlflow.log_param("third_most_important_feature", feature_importance[2][0])
    
    return feature_importance

# %% [markdown]
# Run Model and log it in MLflow

# %%
start_time = time.time()

os.chdir('./experiments/neural_networks') if not load_dotenv() else None
load_dotenv()
print(f"load_dotenv() returned: {load_dotenv()}")
mlflow.set_tracking_uri(os.getenv("MLFLOW_TRACKING_URI"))
mlflow.set_experiment(os.getenv("MLFLOW_EXPERIMENT_NAME"))

# --- lr and batch_size initial values ---
lr = 0.005  # This will be the initial learning rate, will adapt during training
lr_min = 0.0005
batch_size = 16  # Initial batch size instead of fixed batch size
grad_threshold=0.05
batch_multiplier=2
lr_multiplier=0.5
width_1st_layer = 32        
width_2nd_layer = 16
width_3rd_layer = 8
width_4th_layer = 4     
width_output_layer = 1      

# --- Updated params to reflect adaptive nature ---
params = {
    "dataset": data_file_name,
    "width_1st_layer": width_1st_layer,
    "width_2nd_layer": width_2nd_layer,
    "width_3rd_layer": width_3rd_layer,
    "width_4th_layer": width_4th_layer,
    "width_output_layer": width_output_layer,
    "activation": "relu",
    "criterion": "Mean Squared Error (MSE) loss",
    "optimizer": "adam",
    "adaptive_batching_learning_rate": True,  # Flag to indicate adaptive batching
    "initial_lr": lr,  # Renamed to initial_lr
    "initial_batch_size": batch_size,  # Renamed to initial_batch_size
    "max_batch_size": len(X_train),  # Max batch size
    "grad_threshold": grad_threshold,
    "batch_multiplier": batch_multiplier,
    "lr_multiplier": lr_multiplier,
    "lr_min": lr_min
}

# Log to MLflow
run_name = f"Best_lr{lr}_bs{batch_size}_w{width_1st_layer}x{width_2nd_layer}x{width_3rd_layer}x{width_4th_layer}_SHAP"
with mlflow.start_run(run_name=run_name):
    mlflow.log_params(params)

    # Make it reproducible
    SEED = 42
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Define the Neural Network Model
    class FeedforwardNN(nn.Module):
        def __init__(self, input_size):
            super(FeedforwardNN, self).__init__()
            self.layers = nn.Sequential(
                nn.Linear(input_size, width_1st_layer),
                nn.ReLU(),
                nn.Linear(width_1st_layer, width_2nd_layer),
                nn.ReLU(),
                nn.Linear(width_2nd_layer, width_3rd_layer),
                nn.ReLU(),
                nn.Linear(width_3rd_layer, width_4th_layer),
                nn.ReLU(),
                nn.Linear(width_4th_layer, width_output_layer),
            )

        def forward(self, x):
            return self.layers(x)

    model = FeedforwardNN(input_size=X_train.shape[1])
    def init_weights(m):
        '''Make the weight initialization reproducible'''
        if isinstance(m, nn.Linear):
            torch.nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                torch.nn.init.constant_(m.bias, 0.01)
    model.apply(init_weights)      

    # Make GPU work
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Move data to device
    X_train = X_train.to(device)
    y_train = y_train.to(device)
    X_val = X_val.to(device)
    y_val = y_val.to(device)
    X_test = X_test.to(device)
    y_test = y_test.to(device)
    
    # --- Initialize adaptive batch trainer ---
    adaptive_trainer = GradientAdaptiveBatchingLearning(
        initial_batch_size=batch_size,
        initial_lr=lr,
        grad_threshold=grad_threshold,  # Tune this based on your loss scale
        batch_multiplier=batch_multiplier,  # Conservative increase
        lr_multiplier = lr_multiplier,
        lr_min = lr_min,
        max_batch_size=len(X_train)  # Use actual training set size
    )
    
    # Create initial DataLoaders
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    test_dataset = TensorDataset(X_test, y_test)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    # Move model to device
    model = model.to(device)

    # Training with MSE & Logging RMSE, MAE
    def compute_rmse(predictions, targets):
        return torch.sqrt(F.mse_loss(predictions, targets))
    def compute_mae(predictions, targets):
        return torch.mean(torch.abs(predictions - targets))
    def compute_mape(predictions, targets):
        return torch.mean(torch.abs((predictions - targets) / targets) * 100)
    def compute_r2(predictions, targets):
        ss_res = torch.sum((targets - predictions) ** 2)
        ss_tot = torch.sum((targets - torch.mean(targets)) ** 2)
        return 1 - ss_res / ss_tot

    # --- Training loop with adaptive batching ---
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), adaptive_trainer.current_lr)  # Use adaptive LR
    best_val_loss = float('inf')
    patience = 10_000
    trigger_times = 0
    min_delta = 0# -0.01
    train_losses = []
    val_losses = []
    # Track batch size and learning rate history
    batch_size_history = []
    lr_history = []

    progress = tqdm(range(10_001), desc="Training")
    for epoch in progress:
        # Training phase with batches
        model.train()
        epoch_train_loss = 0.0
        num_train_batches = 0
        
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            output = model(batch_X)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            
            epoch_train_loss += loss.item()
            num_train_batches += 1
        
        avg_train_loss = epoch_train_loss / num_train_batches

        # Validation phase with batches
        model.eval()
        epoch_val_loss = 0.0
        num_val_batches = 0
        
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                val_output = model(batch_X)
                val_loss = criterion(val_output, batch_y)
                epoch_val_loss += val_loss.item()
                num_val_batches += 1
        
        avg_val_loss = epoch_val_loss / num_val_batches
        
        # --- Adaptive batch size and learning rate update ---
        new_batch_size, new_lr = adaptive_trainer.update_params(avg_val_loss, epoch)
        
        # Update optimizer learning rate if changed
        if new_lr != optimizer.param_groups[0]['lr']:
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
        
        # Create new dataloader if batch size changed
        if new_batch_size != train_loader.batch_size:
            train_loader = DataLoader(train_dataset, batch_size=new_batch_size, shuffle=True)
            # Also update validation loader for consistency
            val_loader = DataLoader(val_dataset, batch_size=new_batch_size, shuffle=False)
        
        # Track history
        batch_size_history.append(new_batch_size)
        lr_history.append(new_lr)
        
        # For progress display 
        with torch.no_grad():
            sample_output = model(X_train[:new_batch_size])  # Use current batch size
            sample_rmse = compute_rmse(sample_output, y_train[:new_batch_size])
            # Show current batch size in progress
            progress.set_postfix({
                "Loss": avg_train_loss, 
                "RMSE": sample_rmse.item(),
                "BatchSize": new_batch_size,  # Show current batch size
                "LR": f"{new_lr:.6f}"  # Show current learning rate
            })
        
        # Save losses each epoch
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Early stopping logic
        if avg_val_loss + min_delta < best_val_loss:
            best_val_loss = avg_val_loss
            trigger_times = 0
        else:
            trigger_times += 1
            if trigger_times >= patience:
                print(f"\n⏹️ Early stopping at epoch {epoch} — no validation improvement after {patience} epochs.")
                
                model.eval()
                with torch.no_grad():
                    train_output = model(X_train)
                    val_output = model(X_val)
                    train_loss_final = criterion(train_output, y_train)
                    val_loss_final = criterion(val_output, y_val)
                    
                    rmse = compute_rmse(train_output, y_train)
                    mae = compute_mae(train_output, y_train)
                    r2 = compute_r2(train_output, y_train)
                    val_rmse = compute_rmse(val_output, y_val)
                    val_mae = compute_mae(val_output, y_val)
                    val_r2 = compute_r2(val_output, y_val)
                    
                print(f"Train → MSE = {train_loss_final.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
                print(f"Val   → MSE = {val_loss_final.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")
                break

        if epoch % 10_000 == 0:
            model.eval()
            with torch.no_grad():
                train_output = model(X_train)
                val_output = model(X_val)
                train_loss_full = criterion(train_output, y_train)
                val_loss_full = criterion(val_output, y_val)
                
                rmse = compute_rmse(train_output, y_train)
                mae = compute_mae(train_output, y_train)
                r2 = compute_r2(train_output, y_train)
                val_rmse = compute_rmse(val_output, y_val)
                val_mae = compute_mae(val_output, y_val)
                val_r2 = compute_r2(val_output, y_val)
                
            print(f"Epoch {epoch}:")
            print(f"Train → MSE = {train_loss_full.item():.4f}, RMSE = {rmse.item():.4f}, MAE = {mae.item():.4f}, R² = {r2.item():.4f}")
            print(f"Val   → MSE = {val_loss_full.item():.4f}, RMSE = {val_rmse.item():.4f}, MAE = {val_mae.item():.4f}, R² = {val_r2.item():.4f}")

    # Metrics after all the epochs - training
    model.eval()
    with torch.no_grad():
        # Get final predictions on full datasets
        train_output = model(X_train)
        val_output = model(X_val)
        test_output = model(X_test)
        
        # Training metrics
        training_mse = criterion(train_output, y_train)
        training_rmse = compute_rmse(train_output, y_train)
        training_mae = compute_mae(train_output, y_train)
        training_mape = compute_mape(train_output, y_train)
        training_r2_score = compute_r2(train_output, y_train)
    
        # Validation metrics
        val_mse = criterion(val_output, y_val)
        val_rmse = compute_rmse(val_output, y_val)
        val_mae = compute_mae(val_output, y_val)
        val_mape = compute_mape(val_output, y_val)
        val_r2_score = compute_r2(val_output, y_val)

        # Test metrics
        test_loss = criterion(test_output, y_test)
        test_rmse = compute_rmse(test_output, y_test)
        test_mae = compute_mae(test_output, y_test)
        test_mape = compute_mape(test_output, y_test)
        test_r2 = compute_r2(test_output, y_test)
        
        print(f"\nFinal Test Evaluation:")
        print(f"MSE = {test_loss.item():.4f}, RMSE = {test_rmse.item():.4f}, MAE = {test_mae.item():.4f}, R² Score = {test_r2.item():.4f}")

    # Log metrics to MLflow
    # training
    mlflow.log_metric("training_mean_squared_error", round(training_mse.item(), 2))
    mlflow.log_metric("training_root_mean_squared_error", round(training_rmse.item(),2))
    mlflow.log_metric("training_mean_absolute_error", round(training_mae.item(),2))
    mlflow.log_metric("training_mean_absolute_percentage_error", round(training_mape.item(),2))
    mlflow.log_metric("training_r2_score", round(training_r2_score.item(),2))
    # val
    mlflow.log_metric("val_mean_squared_error", round(val_mse.item(), 2))
    mlflow.log_metric("val_rmse", round(val_rmse.item(),2))
    mlflow.log_metric("val_mae", round(val_mae.item(),2))
    mlflow.log_metric("val_mape", round(val_mape.item(),2))
    mlflow.log_metric("val_r2_score", round(val_r2_score.item(),2))
    #test
    mlflow.log_metric("test_mse", round(test_loss.item(),2))
    mlflow.log_metric("test_rmse", round(test_rmse.item(),2))
    mlflow.log_metric("test_mae", round(test_mae.item(),2))
    mlflow.log_metric("test_mape", round(test_mape.item(),2))
    mlflow.log_metric("test_r2_score", round(test_r2.item(),2))

    # Log the model
    X_train_numpy = X_train.detach().cpu().numpy()
    train_output_numpy = train_output.detach().cpu().numpy()
    signature = infer_signature(X_train_numpy, train_output_numpy)
    
    mlflow.pytorch.log_model(
        model,
        name="feed_forward_neural_network",
        signature=signature,
        input_example=X_train_numpy[:5],
        registered_model_name="FNN_Batch_Training"
    )

    # Model summary/architecture
    with open("model_summary.txt", "w") as f:
        f.write(str(model))
    mlflow.log_artifact("model_summary.txt")

    # --- Enhanced plotting with adaptive batching info ---
    start = 100 
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves (existing plot)
    ax1.plot(range(start, len(train_losses)), train_losses[start:], label='Training Loss', color='blue')
    ax1.plot(range(start, len(val_losses)), val_losses[start:], label='Validation Loss', color='orange')
    #ax1.plot(range(start, len(avg_losses)), avg_losses[start:], label='Avg Loss', color='purple')
    #ax1.axvline(x=epoch_min_avg, color='red', linestyle='--', label='Min Avg Loss')
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.set_title("Loss Curves")
    ax1.legend()
    ax1.grid(True)
    plt.savefig("loss_curves.png")
    mlflow.log_artifact("loss_curves.png")
    
    # Batch size evolution
    ax2.plot(batch_size_history, color='green')
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Batch Size")
    ax2.set_title("Batch Size Evolution")
    ax2.grid(True)
    plt.savefig("batch_size_evolution.png")
    mlflow.log_artifact("batch_size_evolution.png")
    
    # Learning rate evolution
    ax3.plot(lr_history, color='red')
    ax3.set_xlabel("Epoch")
    ax3.set_ylabel("Learning Rate")
    ax3.set_title("Learning Rate Evolution")
    ax3.grid(True)
    plt.savefig("learning_rate_evolution.png")
    mlflow.log_artifact("learning_rate_evolution.png")
    
    # Validation loss gradient (to visualize why batch size changed)
    if len(val_losses) > 50:
        val_gradients = np.diff(val_losses)
        ax4.plot(val_gradients[-min(10000, len(val_gradients)):], color='orange', alpha=0.7)
        ax4.axhline(y=adaptive_trainer.grad_threshold, color='red', linestyle='--', 
                   label=f'Threshold: {adaptive_trainer.grad_threshold}')
        ax4.axhline(y=-adaptive_trainer.grad_threshold, color='red', linestyle='--')
        ax4.set_xlabel("Epoch")
        ax4.set_ylabel("Validation Loss Gradient")
        ax4.set_title("Recent Validation Loss Gradient")
        ax4.legend()
        ax4.grid(True)
        plt.savefig("validation_loss_gradient.png")
        mlflow.log_artifact("validation_loss_gradient.png")
    
    plt.tight_layout()
    plt.show()

    # --- Log adaptive batching metrics ---
    mlflow.log_metric("final_batch_size", batch_size_history[-1])
    mlflow.log_metric("final_learning_rate", lr_history[-1])
    mlflow.log_metric("batch_size_increases", len(set(batch_size_history)) - 1)
    
    # Print summary of adaptive batching
    print(f"\n📊 Adaptive Batching Summary:")
    print(f"  Initial batch size: {batch_size}")
    print(f"  Final batch size: {batch_size_history[-1]}")
    print(f"  Initial learning rate: {lr:.6f}")
    print(f"  Final learning rate: {lr_history[-1]:.6f}")
    print(f"  Number of batch size increases: {len(set(batch_size_history)) - 1}")

    # ========================
    # SHAP INTEGRATION - DEEP EXPLAINER
    # ========================

    # --- SHAP MODEL EXPLANATION ---
    print("\n" + "="*60)
    print("🔍 STARTING SHAP MODEL EXPLANATION")
    print("="*60)
    
    try:
        # Define feature names (from your preprocessing)
        feature_names = numerical_cols + list(cat_columns)
        print(f"📋 Features to explain: {feature_names}")
        
        # Generate SHAP explanations
        explainer, shap_values, test_samples, background_data = explain_model_with_shap(
            model=model,
            X_train=X_train,
            X_test=X_test,
            feature_names=feature_names,
            device=device,
            num_background=100,  # Use 100 background samples
            num_explain=20       # Explain 20 test samples
        )
        
        # Create visualizations
        create_shap_visualizations(shap_values, test_samples, background_data, feature_names)
        
        # Analyze feature importance
        feature_importance = analyze_feature_importance(shap_values, feature_names)
        
        # Save SHAP values as artifact
        np.save("shap_values.npy", shap_values)
        np.save("shap_test_samples.npy", test_samples)
        mlflow.log_artifact("shap_values.npy")
        mlflow.log_artifact("shap_test_samples.npy")
        
        print("✅ SHAP analysis completed successfully!")
        
    except Exception as e:
        print(f"❌ Error during SHAP analysis: {str(e)}")
        print("   This might be due to model complexity or memory constraints.")
        mlflow.log_param("shap_analysis_status", "failed")
        mlflow.log_param("shap_error", str(e))
    
    print("="*60)

    # Clean memory in case we want to run this cell again without running the whole notebook
    # remove references to GPU objects 
    del model
    # Invoke garbage collector
    gc.collect()
    # Clear GPU cache
    torch.cuda.empty_cache()

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"\n⏳ Training completed in {elapsed_time:.2f} seconds.")
# Out:
# load_dotenv() returned: True
# Training:   0%|          | 0/10001 [00:00<?, ?it/s]
# Epoch 0:
# Train → MSE = 199904.3594, RMSE = 447.1067, MAE = 425.4728, R² = -9.6591
# Val   → MSE = 187062.2969, RMSE = 432.5070, MAE = 400.5708, R² = -6.1016
# Epoch 68: Gradient = 0.023956 < 0.05
#   → Increased batch size: 16 → 32
#   → Decreased learning rate: 0.005000 → 0.002500
# Epoch 79: Gradient = -0.019916 < 0.05
#   → Increased batch size: 32 → 64
#   → Decreased learning rate: 0.002500 → 0.001250
# Epoch 89: Gradient = -0.015130 < 0.05
#   → Increased batch size: 64 → 128
#   → Decreased learning rate: 0.001250 → 0.000625
# Epoch 99: Gradient = -0.001488 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 109: Gradient = -0.001847 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 119: Gradient = -0.001391 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 129: Gradient = -0.001449 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 139: Gradient = -0.001693 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 149: Gradient = -0.001415 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 159: Gradient = -0.001649 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 169: Gradient = -0.001572 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 179: Gradient = -0.001500 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 189: Gradient = -0.001490 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 199: Gradient = -0.001535 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 209: Gradient = -0.001632 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 219: Gradient = -0.001785 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 229: Gradient = -0.001743 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 239: Gradient = -0.001774 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 249: Gradient = -0.000037 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 259: Gradient = -0.001031 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 269: Gradient = -0.001394 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 279: Gradient = -0.001558 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 289: Gradient = -0.001659 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 299: Gradient = -0.001701 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 309: Gradient = -0.001689 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 319: Gradient = -0.001670 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 329: Gradient = -0.001663 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 339: Gradient = -0.001703 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 349: Gradient = -0.001686 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 359: Gradient = -0.001626 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 369: Gradient = -0.001633 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 379: Gradient = -0.001676 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 389: Gradient = -0.001679 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 399: Gradient = -0.001657 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 409: Gradient = -0.001680 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 419: Gradient = -0.001659 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 429: Gradient = -0.001657 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 439: Gradient = -0.001632 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 449: Gradient = -0.001704 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 459: Gradient = -0.001620 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 469: Gradient = -0.001680 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 479: Gradient = -0.001696 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 489: Gradient = -0.001650 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 499: Gradient = -0.001763 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 509: Gradient = -0.001803 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 519: Gradient = -0.001773 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 529: Gradient = -0.001663 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 539: Gradient = -0.001641 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 549: Gradient = -0.001772 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 559: Gradient = -0.001765 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 569: Gradient = -0.001776 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 579: Gradient = -0.001771 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 589: Gradient = -0.001781 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 599: Gradient = -0.001765 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 609: Gradient = -0.001844 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 619: Gradient = -0.001915 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 629: Gradient = -0.001802 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 639: Gradient = -0.001928 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 649: Gradient = -0.001832 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 659: Gradient = -0.001906 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 669: Gradient = -0.001868 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 679: Gradient = -0.001848 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 689: Gradient = -0.001854 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 699: Gradient = -0.001880 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 709: Gradient = -0.001859 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 719: Gradient = -0.001881 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 729: Gradient = -0.001970 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 739: Gradient = -0.001913 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 749: Gradient = -0.001938 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 759: Gradient = -0.001994 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 769: Gradient = -0.001981 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 779: Gradient = -0.001907 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 789: Gradient = -0.001991 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 799: Gradient = -0.002121 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 809: Gradient = -0.001933 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 819: Gradient = -0.001954 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 829: Gradient = -0.002039 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 839: Gradient = -0.002087 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 849: Gradient = -0.001452 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 859: Gradient = -0.001247 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 869: Gradient = -0.001354 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 879: Gradient = -0.001581 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 889: Gradient = -0.001794 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 899: Gradient = -0.001720 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 909: Gradient = -0.001962 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 919: Gradient = -0.002151 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 929: Gradient = -0.002243 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 939: Gradient = -0.002228 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 949: Gradient = -0.002183 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 959: Gradient = -0.002320 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 969: Gradient = -0.002256 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 979: Gradient = -0.002362 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 989: Gradient = -0.002342 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 999: Gradient = -0.002442 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1009: Gradient = -0.002516 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1019: Gradient = -0.002612 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1029: Gradient = -0.002586 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1039: Gradient = -0.002577 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1049: Gradient = -0.002557 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1059: Gradient = -0.002507 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1069: Gradient = -0.002518 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1079: Gradient = -0.002585 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1089: Gradient = -0.002699 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1099: Gradient = -0.002710 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1109: Gradient = -0.002679 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1119: Gradient = -0.002672 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1129: Gradient = -0.002685 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1139: Gradient = -0.002708 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1149: Gradient = -0.002687 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1159: Gradient = -0.002761 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1169: Gradient = -0.002803 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1179: Gradient = -0.002829 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1189: Gradient = -0.002769 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1199: Gradient = -0.002763 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1209: Gradient = -0.002777 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1219: Gradient = -0.002848 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1229: Gradient = -0.002773 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1239: Gradient = -0.002845 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1249: Gradient = -0.002732 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1259: Gradient = -0.002835 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1269: Gradient = -0.002971 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1279: Gradient = -0.002817 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1289: Gradient = -0.002884 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1299: Gradient = -0.001707 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1309: Gradient = -0.002497 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1319: Gradient = -0.002033 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1329: Gradient = -0.002859 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1339: Gradient = -0.002318 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1349: Gradient = -0.001513 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1359: Gradient = -0.002789 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1369: Gradient = -0.002039 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1379: Gradient = -0.001483 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1389: Gradient = -0.003018 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1399: Gradient = -0.002451 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1409: Gradient = -0.001925 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1419: Gradient = -0.002331 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1429: Gradient = -0.002141 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1439: Gradient = -0.002928 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1449: Gradient = -0.002382 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1459: Gradient = -0.002017 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1469: Gradient = -0.002303 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1479: Gradient = -0.002231 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1489: Gradient = -0.002401 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1499: Gradient = -0.002264 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1509: Gradient = -0.002225 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1519: Gradient = -0.002217 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1529: Gradient = -0.002197 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1539: Gradient = -0.002942 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1549: Gradient = -0.002290 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1559: Gradient = -0.002142 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1569: Gradient = -0.002388 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1579: Gradient = -0.001245 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1589: Gradient = -0.001742 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1599: Gradient = -0.003194 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1609: Gradient = -0.002269 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1619: Gradient = -0.002074 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1629: Gradient = -0.002954 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1639: Gradient = -0.002670 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1649: Gradient = -0.002586 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1659: Gradient = -0.001762 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1669: Gradient = -0.001381 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1679: Gradient = -0.001561 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1689: Gradient = -0.002151 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1699: Gradient = -0.002453 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1709: Gradient = -0.002474 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1719: Gradient = -0.002206 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1729: Gradient = -0.001280 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1739: Gradient = -0.001714 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1749: Gradient = -0.002583 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1759: Gradient = -0.001994 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1769: Gradient = -0.001968 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1779: Gradient = -0.001906 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1789: Gradient = -0.002762 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1799: Gradient = -0.001989 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1809: Gradient = -0.001558 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1819: Gradient = -0.002227 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1829: Gradient = -0.002522 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1839: Gradient = -0.001901 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1849: Gradient = -0.002608 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1859: Gradient = -0.001445 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1869: Gradient = -0.000872 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1879: Gradient = -0.000752 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1889: Gradient = -0.000726 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1899: Gradient = -0.001953 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1909: Gradient = -0.002309 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1919: Gradient = -0.000621 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1929: Gradient = -0.001340 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1939: Gradient = -0.002164 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1949: Gradient = -0.001741 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1959: Gradient = -0.000915 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1969: Gradient = -0.002747 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1979: Gradient = -0.001876 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1989: Gradient = -0.002633 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 1999: Gradient = -0.001979 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2009: Gradient = -0.002144 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2019: Gradient = -0.002593 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2029: Gradient = -0.003180 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2039: Gradient = -0.003301 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2049: Gradient = -0.002848 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2059: Gradient = -0.001889 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2069: Gradient = -0.001976 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2079: Gradient = -0.003132 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2089: Gradient = -0.002078 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2099: Gradient = -0.001262 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2109: Gradient = -0.002072 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2119: Gradient = -0.001367 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2129: Gradient = -0.001626 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2139: Gradient = -0.001877 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2149: Gradient = -0.002285 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2159: Gradient = -0.000580 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2169: Gradient = -0.000005 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2179: Gradient = -0.000339 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2189: Gradient = -0.001207 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2199: Gradient = -0.001768 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2209: Gradient = -0.001522 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2219: Gradient = -0.002233 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2229: Gradient = -0.002014 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2239: Gradient = -0.001768 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2249: Gradient = -0.001308 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2259: Gradient = -0.002315 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2269: Gradient = -0.002318 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2279: Gradient = -0.003109 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2289: Gradient = -0.001943 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2299: Gradient = -0.003578 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2309: Gradient = -0.001997 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2319: Gradient = -0.002207 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2329: Gradient = -0.001963 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2339: Gradient = -0.003430 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2349: Gradient = -0.004120 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2359: Gradient = -0.002444 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2369: Gradient = -0.003055 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2379: Gradient = -0.002573 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2389: Gradient = -0.002604 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2399: Gradient = -0.000953 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2409: Gradient = -0.001366 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2419: Gradient = -0.001726 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2429: Gradient = -0.002211 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2439: Gradient = -0.002040 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2449: Gradient = -0.001915 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2459: Gradient = -0.001533 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2469: Gradient = -0.003238 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2479: Gradient = -0.002640 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2489: Gradient = -0.001096 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2499: Gradient = -0.001859 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2509: Gradient = -0.002856 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2519: Gradient = -0.000793 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2529: Gradient = -0.000486 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2539: Gradient = -0.002594 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2549: Gradient = -0.001501 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2559: Gradient = -0.002195 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2569: Gradient = -0.002099 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2579: Gradient = -0.000872 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2589: Gradient = -0.002625 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2599: Gradient = -0.002178 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2609: Gradient = -0.003509 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2619: Gradient = -0.002006 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2629: Gradient = -0.000890 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2639: Gradient = -0.002800 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2649: Gradient = -0.004561 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2659: Gradient = -0.004239 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2669: Gradient = -0.004350 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2679: Gradient = -0.002311 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2689: Gradient = -0.002684 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2699: Gradient = -0.000347 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2709: Gradient = -0.001415 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2719: Gradient = -0.003705 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2729: Gradient = -0.002643 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2739: Gradient = -0.000376 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2749: Gradient = -0.000939 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2759: Gradient = -0.002742 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2769: Gradient = -0.001286 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2779: Gradient = -0.003168 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2789: Gradient = -0.001161 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2799: Gradient = 0.000764 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2809: Gradient = 0.000213 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2819: Gradient = -0.001924 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2829: Gradient = -0.002718 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2839: Gradient = -0.003145 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2849: Gradient = -0.001208 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2859: Gradient = -0.003134 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2869: Gradient = -0.002976 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2879: Gradient = -0.002451 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2889: Gradient = -0.003899 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2899: Gradient = -0.004855 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2909: Gradient = -0.004745 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2919: Gradient = -0.003953 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2929: Gradient = -0.001790 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2939: Gradient = -0.004313 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2949: Gradient = -0.003643 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2959: Gradient = -0.001283 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2969: Gradient = -0.004275 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2979: Gradient = -0.005321 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2989: Gradient = -0.004228 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 2999: Gradient = -0.002641 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3009: Gradient = -0.002566 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3019: Gradient = -0.002290 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3029: Gradient = -0.002707 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3039: Gradient = -0.000054 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3049: Gradient = -0.000130 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3059: Gradient = -0.002423 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3069: Gradient = -0.002418 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3079: Gradient = -0.002317 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3089: Gradient = -0.003352 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3099: Gradient = -0.001617 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3109: Gradient = -0.001664 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3119: Gradient = -0.001967 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3129: Gradient = -0.002204 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3139: Gradient = -0.002341 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3149: Gradient = -0.002601 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3159: Gradient = -0.002054 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3169: Gradient = -0.001518 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3179: Gradient = -0.003587 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3189: Gradient = -0.000304 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3199: Gradient = -0.003149 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3209: Gradient = -0.002558 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3219: Gradient = -0.001931 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3229: Gradient = -0.000828 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3239: Gradient = -0.003285 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3249: Gradient = -0.002036 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3259: Gradient = -0.001886 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3269: Gradient = -0.002671 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3279: Gradient = -0.004386 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3289: Gradient = -0.002328 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3299: Gradient = -0.000999 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3309: Gradient = -0.003508 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3319: Gradient = -0.002904 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3329: Gradient = -0.001271 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3339: Gradient = -0.001596 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3349: Gradient = -0.001629 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3359: Gradient = -0.000070 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3369: Gradient = 0.000679 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3379: Gradient = -0.001804 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3389: Gradient = -0.001657 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3399: Gradient = -0.002206 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3409: Gradient = -0.002395 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3419: Gradient = -0.001835 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3429: Gradient = -0.001306 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3439: Gradient = -0.003065 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3449: Gradient = -0.002125 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3459: Gradient = -0.002722 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3469: Gradient = -0.001970 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3479: Gradient = -0.001530 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3489: Gradient = -0.000009 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3499: Gradient = -0.003574 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3509: Gradient = -0.002207 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3519: Gradient = -0.002698 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3529: Gradient = -0.000525 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3539: Gradient = -0.001426 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3549: Gradient = -0.000913 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3559: Gradient = -0.000839 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3569: Gradient = -0.002997 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3579: Gradient = -0.000980 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3589: Gradient = -0.001658 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3599: Gradient = -0.001556 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3609: Gradient = -0.002484 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3619: Gradient = -0.000444 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3629: Gradient = -0.002144 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3639: Gradient = -0.001979 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3649: Gradient = -0.000596 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3659: Gradient = -0.001948 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3669: Gradient = -0.002057 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3679: Gradient = -0.001873 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3689: Gradient = -0.001825 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3699: Gradient = -0.001828 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3709: Gradient = -0.001832 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3719: Gradient = -0.001804 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3729: Gradient = -0.001063 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3739: Gradient = -0.002001 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3749: Gradient = -0.001108 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3759: Gradient = -0.002397 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3769: Gradient = -0.000435 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3779: Gradient = -0.003730 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3789: Gradient = -0.002381 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3799: Gradient = -0.001088 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3809: Gradient = -0.000807 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3819: Gradient = -0.001865 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3829: Gradient = -0.000887 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3839: Gradient = -0.001350 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3849: Gradient = -0.001432 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3859: Gradient = -0.000519 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3869: Gradient = -0.001885 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3879: Gradient = 0.000208 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3889: Gradient = -0.001436 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3899: Gradient = -0.002725 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3909: Gradient = -0.000298 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 3919: Gradient = -0.002388 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# ...
# Epoch 9069: Gradient = 0.000138 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9079: Gradient = 0.000673 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9089: Gradient = -0.000487 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9099: Gradient = -0.000496 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9109: Gradient = -0.000203 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9119: Gradient = 0.000101 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9129: Gradient = 0.000022 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9139: Gradient = -0.000293 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9149: Gradient = 0.001113 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9159: Gradient = 0.000793 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9169: Gradient = -0.000992 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9179: Gradient = -0.000788 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9189: Gradient = -0.000250 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9199: Gradient = 0.001142 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9209: Gradient = 0.001083 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9219: Gradient = 0.000152 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9229: Gradient = 0.000247 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9239: Gradient = -0.000443 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9249: Gradient = 0.000323 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9259: Gradient = -0.000788 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9269: Gradient = -0.000873 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9279: Gradient = -0.000170 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9289: Gradient = 0.000085 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9299: Gradient = -0.000094 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9309: Gradient = -0.000339 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9319: Gradient = -0.000472 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9329: Gradient = 0.000437 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9339: Gradient = 0.000058 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9349: Gradient = -0.000460 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9359: Gradient = -0.000935 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9369: Gradient = 0.000251 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9379: Gradient = -0.000097 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9389: Gradient = 0.000340 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9399: Gradient = -0.000175 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9409: Gradient = -0.000164 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9419: Gradient = 0.000302 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9429: Gradient = -0.000905 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9439: Gradient = -0.001048 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9449: Gradient = -0.000532 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9459: Gradient = -0.000107 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9469: Gradient = 0.000764 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9479: Gradient = 0.000471 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9489: Gradient = -0.000073 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9499: Gradient = -0.000494 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9509: Gradient = -0.000364 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9519: Gradient = -0.000218 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9529: Gradient = 0.000156 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9539: Gradient = 0.000604 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9549: Gradient = -0.000533 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9559: Gradient = -0.001173 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9569: Gradient = -0.000925 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9579: Gradient = -0.000238 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9589: Gradient = -0.000123 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9599: Gradient = -0.000312 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9609: Gradient = -0.000410 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9619: Gradient = 0.000301 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9629: Gradient = -0.000247 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9639: Gradient = 0.000171 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9649: Gradient = 0.000525 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9659: Gradient = 0.000825 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9669: Gradient = -0.000121 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9679: Gradient = -0.000763 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9689: Gradient = 0.000504 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9699: Gradient = 0.001057 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9709: Gradient = 0.000252 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9719: Gradient = -0.000334 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9729: Gradient = -0.000315 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9739: Gradient = 0.000059 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9749: Gradient = -0.000184 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9759: Gradient = -0.000233 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9769: Gradient = 0.000296 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9779: Gradient = 0.000200 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9789: Gradient = -0.000758 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9799: Gradient = -0.000119 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9809: Gradient = -0.000035 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9819: Gradient = -0.000087 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9829: Gradient = -0.000659 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9839: Gradient = -0.001606 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9849: Gradient = -0.000497 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9859: Gradient = 0.002150 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9869: Gradient = 0.000338 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9879: Gradient = 0.000417 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9889: Gradient = 0.001286 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9899: Gradient = -0.000252 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9909: Gradient = -0.000059 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9919: Gradient = 0.001430 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9929: Gradient = 0.001143 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9939: Gradient = -0.002859 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9949: Gradient = 0.000837 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9959: Gradient = 0.000988 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9969: Gradient = 0.000602 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9979: Gradient = -0.000393 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9989: Gradient = 0.000602 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 9999: Gradient = 0.002497 < 0.05
#   → Increased batch size: 95 → 190
#   → Decreased learning rate: 0.001000 → 0.000500
# Epoch 10000:
# Train → MSE = 0.1512, RMSE = 0.3889, MAE = 0.2698, R² = 1.0000
# Val   → MSE = 0.5125, RMSE = 0.7159, MAE = 0.3490, R² = 1.0000
#
# Final Test Evaluation:
# MSE = 0.7831, RMSE = 0.8850, MAE = 0.4391, R² Score = 1.0000
# 2025/07/31 16:33:46 WARNING mlflow.utils.requirements_utils: Found torch version (2.7.1+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.7.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2025/07/31 16:33:54 WARNING mlflow.utils.requirements_utils: Found torch version (2.7.1+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.7.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# Downloading artifacts:   0%|          | 0/8 [00:00<?, ?it/s]
# Registered model 'FNN_Batch_Training' already exists. Creating a new version of this model...
# 2025/07/31 16:33:56 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: FNN_Batch_Training, version 15
# Created version '15' of model 'FNN_Batch_Training'.
# 📊 Adaptive Batching Summary:
#   Initial batch size: 16
#   Final batch size: 190
#   Initial learning rate: 0.005000
#   Final learning rate: 0.000500
#   Number of batch size increases: 4
#
# ============================================================
# 🔍 STARTING SHAP MODEL EXPLANATION
# ============================================================
# 📋 Features to explain: ['age', 'annual_income', 'loyalty_score', 'purchase_frequency', 'spend_per_purchase', 'spend_to_income_ratio', 'log_annual_income', 'log_purchase_frequency', 'region_grouped_North', 'region_grouped_South', 'region_grouped_West']
# 🔍 Generating SHAP explanations...
# ✅ SHAP values calculated for 20 samples
#    SHAP values shape: (20, 11, 1)
# 📊 Creating SHAP visualizations...
# C:\Users\The Winner\AppData\Local\Temp\ipykernel_11212\2316092941.py:57: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, test_samples, feature_names=feature_names, plot_type="bar", show=False)
# c:\miniconda3\envs\gtx1060_tf\lib\site-packages\shap\plots\_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# C:\Users\The Winner\AppData\Local\Temp\ipykernel_11212\2316092941.py:66: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, test_samples, feature_names=feature_names, show=False)
# c:\miniconda3\envs\gtx1060_tf\lib\site-packages\shap\plots\_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# 🏆 Feature Importance Ranking (by mean |SHAP value|):
#    1. region_grouped_South     : 79.4696
#    2. region_grouped_West      : 72.1345
#    3. region_grouped_North     : 70.6698
#    4. log_purchase_frequency   : 42.7977
#    5. spend_per_purchase       : 31.7993
#    6. purchase_frequency       : 17.9755
#    7. annual_income            : 17.8335
#    8. spend_to_income_ratio    : 12.7504
#    9. age                      : 5.2100
#   10. log_annual_income        : 3.4180
#   11. loyalty_score            : 3.0331
# ✅ SHAP analysis completed successfully!
# ============================================================
#
# ⏳ Training completed in 125.82 seconds.
# 🏃 View run Best_lr0.005_bs16_w32x16x8x4_SHAP at: http://localhost:5000/#/experiments/408745732833894938/runs/862a4cde1f15425f91362bf8c3eca184
# 🧪 View experiment at: http://localhost:5000/#/experiments/408745732833894938
